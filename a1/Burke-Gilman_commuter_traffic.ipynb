# %% [markdown]
# # Tracking traffic on the Burke Gilman trail
# This notebook will walk you through the process of exploring traffic patterns on the Burke Gilman trail, and asking and answering specific research questions using that data. The data we're using today comes from [data.seattle.gov](https://data.seattle.gov/) which is an online portal where the city of Seattle hosts publicly-available datasets.
#
# The exercises below will use the [Burke Gilman trail north of NE 70th St Bicycle and Pedestrian Counter](https://data.seattle.gov/Transportation/Burke-Gilman-Trail-north-of-NE-70th-St-Bicycle-and/2z5v-ecg8) dataset, which collects north and south traffic by bicyclists and pedestrians on a high-traffic portion of the Burke Gilman trail.

# %% [markdown]
# # Gathering the data
# Our first step here is to gather a sample of the data to work with. The full dataset is 53,000 rows, but we can use an API query to specify what time range we want to look at, so that we don't need to download the entire dataset. For now, we'll grab one year's worth of data—2019.
#
# If you want more practice with the Seattle Open Data API, you can use the notebook ``SODA_API_demo.ipynb``.

# %%
#download the requests library, a bundle of code that is useful for sending and retrieving data over the internet
import requests

# %%
#the URL we're retrieving the data from. Copy/paste it into your browser to view it!
api_endpoint = "https://data.seattle.gov/resource/2z5v-ecg8.json?"

#the parameters we're passing to the API, to specify what subset of data we want.
api_parameters = "$limit=50000&$where=date > '2019-01-01T00:00:00' AND date < '2020-01-01T00:00:00'"

# %% [markdown]
# Now we will combine these two strings into a single long URL, which is our API request. It ends up looking like this (run the cell below).

# %%
print(api_endpoint + api_parameters)
# Out:
# https://data.seattle.gov/resource/2z5v-ecg8.json?$limit=50000&$where=date > '2019-01-01T00:00:00' AND date < '2020-01-01T00:00:00'

# %% [markdown]
# Copy and paste that full string into your browser to get a sneak peak at the data we'll be working with!

# %%
#request the data from the API
api_request = requests.get(api_endpoint + api_parameters)

#turn this data into a list of dictionaries, so that we can work with it in Python
raw_data = api_request.json()

# %% [markdown]
# Now we have the data, let's see what it looks like...

# %%
#how many rows are in our dataset?
print(len(raw_data))
# Out:
# 8759

# %%
print(raw_data)
# Out:
# [{'date': '2019-01-01T01:00:00.000', 'bgt_north_of_ne_70th_total': '2', 'ped_south': '1', 'ped_north': '0', 'bike_north': '1', 'bike_south': '0'}, {'date': '2019-01-01T02:00:00.000', 'bgt_north_of_ne_70th_total': '1', 'ped_south': '0', 'ped_north': '0', 'bike_north': '0', 'bike_south': '1'}, {'date': '2019-01-01T03:00:00.000', 'bgt_north_of_ne_70th_total': '0', 'ped_south': '0', 'ped_north': '0', 'bike_north': '0', 'bike_south': '0'}, {'date': '2019-01-01T04:00:00.000', 'bgt_north_of_ne_70th_total': '1', 'ped_south': '0', 'ped_north': '0', 'bike_north': '1', 'bike_south': '0'}, {'date': '2019-01-01T05:00:00.000', 'bgt_north_of_ne_70th_total': '1', 'ped_south': '0', 'ped_north': '0', 'bike_north': '1', 'bike_south': '0'}, {'date': '2019-01-01T06:00:00.000', 'bgt_north_of_ne_70th_total': '2', 'ped_south': '0', 'ped_north': '0', 'bike_north': '1', 'bike_south': '1'}, {'date': '2019-01-01T07:00:00.000', 'bgt_north_of_ne_70th_total': '5', 'ped_south': '1', 'ped_north': '0', 'bike_north': '2', 'bike_south': '2'}, {'date': '2019-01-01T08:00:00.000', 'bgt_north_of_ne_70th_total': '17', 'ped_south': '8', 'ped_north': '3', 'bike_north': '1', 'bike_south': '5'}, {'date': '2019-01-01T09:00:00.000', 'bgt_north_of_ne_70th_total': '57', 'ped_south': '18', 'ped_north': '17', 'bike_north': '12', 'bike_south': '10'}, {'date': '2019-01-01T10:00:00.000', 'bgt_north_of_ne_70th_total': '87', 'ped_south': '20', 'ped_north': '29', 'bike_north': '12', 'bike_south': '26'}, {'date': '2019-01-01T11:00:00.000', 'bgt_north_of_ne_70th_total': '137', 'ped_south': '28', 'ped_north': '18', 'bike_north': '34', 'bike_south': '57'}, {'date': '2019-01-01T12:00:00.000', 'bgt_north_of_ne_70th_total': '104', 'ped_south': '20', 'ped_north': '17', 'bike_north': '25', 'bike_south': '42'}, {'date': '2019-01-01T13:00:00.000', 'bgt_north_of_ne_70th_total': '134', 'ped_south': '15', 'ped_north': '24', 'bike_north': '42', 'bike_south': '53'}, {'date': '2019-01-01T14:00:00.000', 'bgt_north_of_ne_70th_total': '146', 'ped_south': '18', 'ped_north': '22', 'bike_north': '53', 'bike_south': '53'}, {'date': '2019-01-01T15:00:00.000', 'bgt_north_of_ne_70th_total': '105', 'ped_south': '24', 'ped_north': '22', 'bike_north': '41', 'bike_south': '18'}, {'date': '2019-01-01T16:00:00.000', 'bgt_north_of_ne_70th_total': '55', 'ped_south': '16', 'ped_north': '20', 'bike_north': '11', 'bike_south': '8'}, {'date': '2019-01-01T17:00:00.000', 'bgt_north_of_ne_70th_total': '12', 'ped_south': '2', 'ped_north': '5', 'bike_north': '3', 'bike_south': '2'}, {'date': '2019-01-01T18:00:00.000', 'bgt_north_of_ne_70th_total': '15', 'ped_south': '4', 'ped_north': '4', 'bike_north': '4', 'bike_south': '3'}, {'date': '2019-01-01T19:00:00.000', 'bgt_north_of_ne_70th_total': '4', 'ped_south': '1', 'ped_north': '2', 'bike_north': '1', 'bike_south': '0'}, {'date': '2019-01-01T20:00:00.000', 'bgt_north_of_ne_70th_total': '2', 'ped_south': '0', 'ped_north': '1', 'bike_north': '0', 'bike_south': '1'}, {'date': '2019-01-01T21:00:00.000', 'bgt_north_of_ne_70th_total': '3', 'ped_south': '1', 'ped_north': '2', 'bike_north': '0', 'bike_south': '0'}, {'date': '2019-01-01T22:00:00.000', 'bgt_north_of_ne_70th_total': '3', 'ped_south': '1', 'ped_north': '0', 'bike_north': '0', 'bike_south': '2'}, {'date': '2019-01-01T23:00:00.000', 'bgt_north_of_ne_70th_total': '0', 'ped_south': '0', 'ped_north': '0', 'bike_north': '0', 'bike_south': '0'}, {'date': '2019-01-02T00:00:00.000', 'bgt_north_of_ne_70th_total': '0', 'ped_south': '0', 'ped_north': '0', 'bike_north': '0', 'bike_south': '0'}, {'date': '2019-01-02T01:00:00.000', 'bgt_north_of_ne_70th_total': '0', 'ped_south': '0', 'ped_north': '0', 'bike_north': '0', 'bike_south': '0'}, {'date': '2019-01-02T02:00:00.000', 'bgt_north_of_ne_70th_total': '0', 'ped_south': '0', 'ped_north': '0', 'bike_north': '0', 'bike_south': '0'}, {'date': '2019-01-02T03:00:00.000', 'bgt_north_of_ne_70th_total': '0', 'ped_south': '0', 'ped_north': '0', 'bike_north': '0', 'bike_south': '0'}, {'date': ' ...

# %% [markdown]
# That's kind of hard to read, isn't it? Fortunately, there's another useful Python library called "pretty print" (``pprint``), that we can use to make it easier to read this data structure.

# %%
#import the pretty print library
from pprint import pprint

# %% [markdown]
# You use ``pprint`` the same way you use ``print``

# %%
pprint(raw_data)
# Out:
# [{'bgt_north_of_ne_70th_total': '2',
#   'bike_north': '1',
#   'bike_south': '0',
#   'date': '2019-01-01T01:00:00.000',
#   'ped_north': '0',
#   'ped_south': '1'},
#  {'bgt_north_of_ne_70th_total': '1',
#   'bike_north': '0',
#   'bike_south': '1',
#   'date': '2019-01-01T02:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '0',
#   'bike_north': '0',
#   'bike_south': '0',
#   'date': '2019-01-01T03:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '1',
#   'bike_north': '1',
#   'bike_south': '0',
#   'date': '2019-01-01T04:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '1',
#   'bike_north': '1',
#   'bike_south': '0',
#   'date': '2019-01-01T05:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '2',
#   'bike_north': '1',
#   'bike_south': '1',
#   'date': '2019-01-01T06:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '5',
#   'bike_north': '2',
#   'bike_south': '2',
#   'date': '2019-01-01T07:00:00.000',
#   'ped_north': '0',
#   'ped_south': '1'},
#  {'bgt_north_of_ne_70th_total': '17',
#   'bike_north': '1',
#   'bike_south': '5',
#   'date': '2019-01-01T08:00:00.000',
#   'ped_north': '3',
#   'ped_south': '8'},
#  {'bgt_north_of_ne_70th_total': '57',
#   'bike_north': '12',
#   'bike_south': '10',
#   'date': '2019-01-01T09:00:00.000',
#   'ped_north': '17',
#   'ped_south': '18'},
#  {'bgt_north_of_ne_70th_total': '87',
#   'bike_north': '12',
#   'bike_south': '26',
#   'date': '2019-01-01T10:00:00.000',
#   'ped_north': '29',
#   'ped_south': '20'},
#  {'bgt_north_of_ne_70th_total': '137',
#   'bike_north': '34',
#   'bike_south': '57',
#   'date': '2019-01-01T11:00:00.000',
#   'ped_north': '18',
#   'ped_south': '28'},
#  {'bgt_north_of_ne_70th_total': '104',
#   'bike_north': '25',
#   'bike_south': '42',
#   'date': '2019-01-01T12:00:00.000',
#   'ped_north': '17',
#   'ped_south': '20'},
#  {'bgt_north_of_ne_70th_total': '134',
#   'bike_north': '42',
#   'bike_south': '53',
#   'date': '2019-01-01T13:00:00.000',
#   'ped_north': '24',
#   'ped_south': '15'},
#  {'bgt_north_of_ne_70th_total': '146',
#   'bike_north': '53',
#   'bike_south': '53',
#   'date': '2019-01-01T14:00:00.000',
#   'ped_north': '22',
#   'ped_south': '18'},
#  {'bgt_north_of_ne_70th_total': '105',
#   'bike_north': '41',
#   'bike_south': '18',
#   'date': '2019-01-01T15:00:00.000',
#   'ped_north': '22',
#   'ped_south': '24'},
#  {'bgt_north_of_ne_70th_total': '55',
#   'bike_north': '11',
#   'bike_south': '8',
#   'date': '2019-01-01T16:00:00.000',
#   'ped_north': '20',
#   'ped_south': '16'},
#  {'bgt_north_of_ne_70th_total': '12',
#   'bike_north': '3',
#   'bike_south': '2',
#   'date': '2019-01-01T17:00:00.000',
#   'ped_north': '5',
#   'ped_south': '2'},
#  {'bgt_north_of_ne_70th_total': '15',
#   'bike_north': '4',
#   'bike_south': '3',
#   'date': '2019-01-01T18:00:00.000',
#   'ped_north': '4',
#   'ped_south': '4'},
#  {'bgt_north_of_ne_70th_total': '4',
#   'bike_north': '1',
#   'bike_south': '0',
#   'date': '2019-01-01T19:00:00.000',
#   'ped_north': '2',
#   'ped_south': '1'},
#  {'bgt_north_of_ne_70th_total': '2',
#   'bike_north': '0',
#   'bike_south': '1',
#   'date': '2019-01-01T20:00:00.000',
#   'ped_north': '1',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '3',
#   'bike_north': '0',
#   'bike_south': '0',
#   'date': '2019-01-01T21:00:00.000',
#   'ped_north': '2',
#   'ped_south': '1'},
#  {'bgt_north_of_ne_70th_total': '3',
#   'bike_north': '0',
#   'bike_south': '2',
#   'date': '2019-01-01T22:00:00.000',
#   'ped_north': '0',
#   'ped_south': '1'},
#  {'bgt_north_of_ne_70th_total': '0',
#   'bike_north': '0',
#   'bike_south': '0',
#   'date': '2019-01-01T23:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '0',
#   'bike_north': '0',
#   'bike_south': '0',
#   'date': '2019-01-02T00:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '0',
#   'bike_north': '0',
#   'bike_south': '0',
#   'date': '2019-01-02T01:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '0',
#   'bike_north': '0',
#   'bike_south': '0',
#   'date': '2019-01-02T02:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '0',
#   'bike_north': '0',
#   'bike_south': '0',
#   'date': '2019-01-02T03:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '1',
#   'bike_north': '1',
#   'bike_south': '0',
#   'date': '2019-01-02T04:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '11',
#   'bike_north': '8',
#   'bike_south': '0',
#   'date': '2019-01-02T05:00:00.000',
#   'ped_north': '2',
#   'ped_south': '1'},
#  {'bgt_north_of_ne_70th_total': '25',
#   'bike_north': '22',
#   'bike_south': '1',
#   'date': '2019-01-02T06:00:00.000',
#   'ped_north': '2',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '32',
#   'bike_north': '26',
#   'bike_south': '0',
#   'date': '2019-01-02T07:00:00.000',
#   'ped_north': '3',
#   'ped_south': '3'},
#  {'bgt_north_of_ne_70th_total': '62',
#   'bike_north': '40',
#   'bike_south': '7',
#   'date': '2019-01-02T08:00:00.000',
#   'ped_north': '7',
#   'ped_south': '8'},
#  {'bgt_north_of_ne_70th_total': '54',
#   'bike_north': '21',
#   'bike_south': '8',
#   'date': '2019-01-02T09:00:00.000',
#   'ped_north': '15',
#   'ped_south': '10'},
#  {'bgt_north_of_ne_70th_total': '31',
#   'bike_north': '11',
#   'bike_south': '7',
#   'date': '2019-01-02T10:00:00.000',
#   'ped_north': '8',
#   'ped_south': '5'},
#  {'bgt_north_of_ne_70th_total': '35',
#   'bike_north': '8',
#   'bike_south': '4',
#   'date': '2019-01-02T11:00:00.000',
#   'ped_north': '12',
#   'ped_south': '11'},
#  {'bgt_north_of_ne_70th_total': '40',
#   'bike_north': '9',
#   'bike_south': '12',
#   'date': '2019-01-02T12:00:00.000',
#   'ped_north': '11',
#   'ped_south': '8'},
#  {'bgt_north_of_ne_70th_total': '47',
#   'bike_north': '13',
#   'bike_south': '15',
#   'date': '2019-01-02T13:00:00.000',
#   'ped_north': '10',
#   'ped_south': '9'},
#  {'bgt_north_of_ne_70th_total': '45',
#   'bike_north': '12',
#   'bike_south': '12',
#   'date': '2019-01-02T14:00:00.000',
#   'ped_north': '6',
#   'ped_south': '15'},
#  {'bgt_north_of_ne_70th_total': '53',
#   'bike_north': '5',
#   'bike_south': '23',
#   'date': '2019-01-02T15:00:00.000',
#   'ped_north': '9',
#   'ped_south': '16'},
#  {'bgt_north_of_ne_70th_total': '71',
#   'bike_north': '18',
#   'bike_south': '28',
#   'date': '2019-01-02T16:00:00.000',
#   'ped_north': '11',
#   'ped_south': '14'},
#  {'bgt_north_of_ne_70th_total': '72',
#   'bike_north': '6',
#   'bike_south': '57',
#   'date': '2019-01-02T17:00:00.000',
#   'ped_north': '4',
#   'ped_south': '5'},
#  {'bgt_north_of_ne_70th_total': '34',
#   'bike_north': '4',
#   'bike_south': '30',
#   'date': '2019-01-02T18:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '21',
#   'bike_north': '4',
#   'bike_south': '12',
#   'date': '2019-01-02T19:00:00.000',
#   'ped_north': '3',
#   'ped_south': '2'},
#  {'bgt_north_of_ne_70th_total': '5',
#   'bike_north': '0',
#   'bike_south': '5',
#   'date': '2019-01-02T20:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '4',
#   'bike_north': '4',
#   'bike_south': '0',
#   'date': '2019-01-02T21:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '1',
#   'bike_north': '0',
#   'bike_south': '1',
#   'date': '2019-01-02T22:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '1',
#   'bike_north': '0',
#   'bike_south': '1',
#   'date': '2019-01-02T23:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '0',
#   'bike_north': '0',
#   'bike_south': '0',
#   'date': '2019-01-03T00:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '0',
#   'bike_north': '0',
#   'bike_south': '0',
#   'date': '2019-01-03T01:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '0',
#   'bike_north': '0',
#   'bike_south': '0',
#   'date': '2019-01-03T02:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '0',
#   'bike_north': '0',
#   'bike_south': '0',
#   'date': '2019-01-03T03:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '2',
#   'bike_north': '2',
#   'bike_south': '0',
#   'date': '2019-01-03T04:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '8',
#   'bike_north': '7',
#   'bike_south': '1',
#   'date': '2019-01-03T05:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '20',
#   'bike_north': '15',
#   'bike_south': '1',
#   'date': '2019-01-03T06:00:00.000',
#   'ped_north': '2',
#   'ped_south': '2'},
#  {'bgt_north_of_ne_70th_total': '32',
#   'bike_north': '23',
#   'bike_south': '3',
#   'date': '2019-01-03T07:00:00.000',
#   'ped_north': '5',
#   'ped_south': '1'},
#  {'bgt_north_of_ne_70th_total': '46',
#   'bike_north': '25',
#   'bike_south': '3',
#   'date': '2019-01-03T08:00:00.000',
#   'ped_north': '10',
#   'ped_south': '8'},
#  {'bgt_north_of_ne_70th_total': '35',
#   'bike_north': '16',
#   'bike_south': '3',
#   'date': '2019-01-03T09:00:00.000',
#   'ped_north': '8',
#   'ped_south': '8'},
#  {'bgt_north_of_ne_70th_total': '27',
#   'bike_north': '3',
#   'bike_south': '3',
#   'date': '2019-01-03T10:00:00.000',
#   'ped_north': '9',
#   'ped_south': '12'},
#  {'bgt_north_of_ne_70th_total': '26',
#   'bike_north': '8',
#   'bike_south': '7',
#   'date': '2019-01-03T11:00:00.000',
#   'ped_north': '6',
#   'ped_south': '5'},
#  {'bgt_north_of_ne_70th_total': '33',
#   'bike_north': '6',
#   'bike_south': '4',
#   'date': '2019-01-03T12:00:00.000',
#   'ped_north': '13',
#   'ped_south': '10'},
#  {'bgt_north_of_ne_70th_total': '30',
#   'bike_north': '4',
#   'bike_south': '7',
#   'date': '2019-01-03T13:00:00.000',
#   'ped_north': '10',
#   'ped_south': '9'},
#  {'bgt_north_of_ne_70th_total': '20',
#   'bike_north': '7',
#   'bike_south': '7',
#   'date': '2019-01-03T14:00:00.000',
#   'ped_north': '4',
#   'ped_south': '2'},
#  {'bgt_north_of_ne_70th_total': '19',
#   'bike_north': '1',
#   'bike_south': '9',
#   'date': '2019-01-03T15:00:00.000',
#   'ped_north': '5',
#   'ped_south': '4'},
#  {'bgt_north_of_ne_70th_total': '29',
#   'bike_north': '3',
#   'bike_south': '19',
#   'date': '2019-01-03T16:00:00.000',
#   'ped_north': '4',
#   'ped_south': '3'},
#  {'bgt_north_of_ne_70th_total': '47',
#   'bike_north': '4',
#   'bike_south': '30',
#   'date': '2019-01-03T17:00:00.000',
#   'ped_north': '8',
#   'ped_south': '5'},
#  {'bgt_north_of_ne_70th_total': '28',
#   'bike_north': '4',
#   'bike_south': '20',
#   'date': '2019-01-03T18:00:00.000',
#   'ped_north': '1',
#   'ped_south': '3'},
#  {'bgt_north_of_ne_70th_total': '15',
#   'bike_north': '1',
#   'bike_south': '12',
#   'date': '2019-01-03T19:00:00.000',
#   'ped_north': '2',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '2',
#   'bike_north': '0',
#   'bike_south': '1',
#   'date': '2019-01-03T20:00:00.000',
#   'ped_north': '1',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '2',
#   'bike_north': '1',
#   'bike_south': '1',
#   'date': '2019-01-03T21:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '0',
#   'bike_north': '0',
#   'bike_south': '0',
#   'date': '2019-01-03T22:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '0',
#   'bike_north': '0',
#   'bike_south': '0',
#   'date': '2019-01-03T23:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '0',
#   'bike_north': '0',
#   'bike_south': '0',
#   'date': '2019-01-04T00:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '0',
#   'bike_north': '0',
#   'bike_south': '0',
#   'date': '2019-01-04T01:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '0',
#   'bike_north': '0',
#   'bike_south': '0',
#   'date': '2019-01-04T02:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '2',
#   'bike_north': '0',
#   'bike_south': '2',
#   'date': '2019-01-04T03:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '1',
#   'bike_north': '1',
#   'bike_south': '0',
#   'date': '2019-01-04T04:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '6',
#   'bike_north': '4',
#   'bike_south': '2',
#   'date': '2019-01-04T05:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '18',
#   'bike_north': '14',
#   'bike_south': '1',
#   'date': '2019-01-04T06:00:00.000',
#   'ped_north': '1',
#   'ped_south': '2'},
#  {'bgt_north_of_ne_70th_total': '35',
#   'bike_north': '23',
#   'bike_south': '5',
#   'date': '2019-01-04T07:00:00.000',
#   'ped_north': '4',
#   'ped_south': '3'},
#  {'bgt_north_of_ne_70th_total': '67',
#   'bike_north': '37',
#   'bike_south': '8',
#   'date': '2019-01-04T08:00:00.000',
#   'ped_north': '11',
#   'ped_south': '11'},
#  {'bgt_north_of_ne_70th_total': '50',
#   'bike_north': '25',
#   'bike_south': '8',
#   'date': '2019-01-04T09:00:00.000',
#   'ped_north': '11',
#   'ped_south': '6'},
#  {'bgt_north_of_ne_70th_total': '52',
#   'bike_north': '14',
#   'bike_south': '10',
#   'date': '2019-01-04T10:00:00.000',
#   'ped_north': '14',
#   'ped_south': '14'},
#  {'bgt_north_of_ne_70th_total': '43',
#   'bike_north': '11',
#   'bike_south': '11',
#   'date': '2019-01-04T11:00:00.000',
#   'ped_north': '8',
#   'ped_south': '13'},
#  {'bgt_north_of_ne_70th_total': '75',
#   'bike_north': '18',
#   'bike_south': '23',
#   'date': '2019-01-04T12:00:00.000',
#   'ped_north': '16',
#   'ped_south': '18'},
#  {'bgt_north_of_ne_70th_total': '62',
#   'bike_north': '19',
#   'bike_south': '15',
#   'date': '2019-01-04T13:00:00.000',
#   'ped_north': '17',
#   'ped_south': '11'},
#  {'bgt_north_of_ne_70th_total': '50',
#   'bike_north': '11',
#   'bike_south': '18',
#   'date': '2019-01-04T14:00:00.000',
#   'ped_north': '12',
#   'ped_south': '9'},
#  {'bgt_north_of_ne_70th_total': '77',
#   'bike_north': '20',
#   'bike_south': '28',
#   'date': '2019-01-04T15:00:00.000',
#   'ped_north': '14',
#   'ped_south': '15'},
#  {'bgt_north_of_ne_70th_total': '53',
#   'bike_north': '14',
#   'bike_south': '26',
#   'date': '2019-01-04T16:00:00.000',
#   'ped_north': '7',
#   'ped_south': '6'},
#  {'bgt_north_of_ne_70th_total': '62',
#   'bike_north': '4',
#   'bike_south': '46',
#   'date': '2019-01-04T17:00:00.000',
#   'ped_north': '4',
#   'ped_south': '8'},
#  {'bgt_north_of_ne_70th_total': '32',
#   'bike_north': '3',
#   'bike_south': '24',
#   'date': '2019-01-04T18:00:00.000',
#   'ped_north': '4',
#   'ped_south': '1'},
#  {'bgt_north_of_ne_70th_total': '11',
#   'bike_north': '0',
#   'bike_south': '9',
#   'date': '2019-01-04T19:00:00.000',
#   'ped_north': '0',
#   'ped_south': '2'},
#  {'bgt_north_of_ne_70th_total': '9',
#   'bike_north': '2',
#   'bike_south': '5',
#   'date': '2019-01-04T20:00:00.000',
#   'ped_north': '2',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '4',
#   'bike_north': '2',
#   'bike_south': '2',
#   'date': '2019-01-04T21:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '1',
#   'bike_north': '0',
#   'bike_south': '1',
#   'date': '2019-01-04T22:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '1',
#   'bike_north': '1',
#   'bike_south': '0',
#   'date': '2019-01-04T23:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '0',
#   'bike_north': '0',
#   'bike_south': '0',
#   'date': '2019-01-05T00:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '0',
#   'bike_north': '0',
#   'bike_south': '0',
#   'date': '2019-01-05T01:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '0',
#   'bike_north': '0',
#   'bike_south': '0',
#   'date': '2019-01-05T02:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '0',
#   'bike_north': '0',
#   'bike_south': '0',
#   'date': '2019-01-05T03:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '1',
#   'bike_north': '0',
#   'bike_south': '1',
#   'date': '2019-01-05T04:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '2',
#   'bike_north': '2',
#   'bike_south': '0',
#   'date': '2019-01-05T05:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '9',
#   'bike_north': '2',
#   'bike_south': '1',
#   'date': '2019-01-05T06:00:00.000',
#   'ped_north': '3',
#   'ped_south': '3'},
#  {'bgt_north_of_ne_70th_total': '14',
#   'bike_north': '5',
#   'bike_south': '4',
#   'date': '2019-01-05T07:00:00.000',
#   'ped_north': '2',
#   'ped_south': '3'},
#  {'bgt_north_of_ne_70th_total': '84',
#   'bike_north': '10',
#   'bike_south': '28',
#   'date': '2019-01-05T08:00:00.000',
#   'ped_north': '23',
#   'ped_south': '23'},
#  {'bgt_north_of_ne_70th_total': '158',
#   'bike_north': '32',
#   'bike_south': '62',
#   'date': '2019-01-05T09:00:00.000',
#   'ped_north': '23',
#   'ped_south': '41'},
#  {'bgt_north_of_ne_70th_total': '138',
#   'bike_north': '39',
#   'bike_south': '48',
#   'date': '2019-01-05T10:00:00.000',
#   'ped_north': '33',
#   'ped_south': '18'},
#  {'bgt_north_of_ne_70th_total': '141',
#   'bike_north': '38',
#   'bike_south': '50',
#   'date': '2019-01-05T11:00:00.000',
#   'ped_north': '22',
#   'ped_south': '31'},
#  {'bgt_north_of_ne_70th_total': '179',
#   'bike_north': '61',
#   'bike_south': '59',
#   'date': '2019-01-05T12:00:00.000',
#   'ped_north': '32',
#   'ped_south': '27'},
#  {'bgt_north_of_ne_70th_total': '142',
#   'bike_north': '49',
#   'bike_south': '47',
#   'date': '2019-01-05T13:00:00.000',
#   'ped_north': '26',
#   'ped_south': '20'},
#  {'bgt_north_of_ne_70th_total': '124',
#   'bike_north': '52',
#   'bike_south': '39',
#   'date': '2019-01-05T14:00:00.000',
#   'ped_north': '20',
#   'ped_south': '13'},
#  {'bgt_north_of_ne_70th_total': '109',
#   'bike_north': '41',
#   'bike_south': '37',
#   'date': '2019-01-05T15:00:00.000',
#   'ped_north': '10',
#   'ped_south': '21'},
#  {'bgt_north_of_ne_70th_total': '73',
#   'bike_north': '23',
#   'bike_south': '15',
#   'date': '2019-01-05T16:00:00.000',
#   'ped_north': '19',
#   'ped_south': '16'},
#  {'bgt_north_of_ne_70th_total': '23',
#   'bike_north': '11',
#   'bike_south': '3',
#   'date': '2019-01-05T17:00:00.000',
#   'ped_north': '6',
#   'ped_south': '3'},
#  {'bgt_north_of_ne_70th_total': '3',
#   'bike_north': '1',
#   'bike_south': '1',
#   'date': '2019-01-05T18:00:00.000',
#   'ped_north': '0',
#   'ped_south': '1'},
#  {'bgt_north_of_ne_70th_total': '2',
#   'bike_north': '0',
#   'bike_south': '2',
#   'date': '2019-01-05T19:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '4',
#   'bike_north': '1',
#   'bike_south': '1',
#   'date': '2019-01-05T20:00:00.000',
#   'ped_north': '2',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '3',
#   'bike_north': '0',
#   'bike_south': '3',
#   'date': '2019-01-05T21:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '0',
#   'bike_north': '0',
#   'bike_south': '0',
#   'date': '2019-01-05T22:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '0',
#   'bike_north': '0',
#   'bike_south': '0',
#   'date': '2019-01-05T23:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '0',
#   'bike_north': '0',
#   'bike_south': '0',
#   'date': '2019-01-06T00:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '0',
#   'bike_north': '0',
#   'bike_south': '0',
#   'date': '2019-01-06T01:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '0',
#   'bike_north': '0',
#   'bike_south': '0',
#   'date': '2019-01-06T02:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '0',
#   'bike_north': '0',
#   'bike_south': '0',
#   'date': '2019-01-06T03:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '0',
#   'bike_north': '0',
#   'bike_south': '0',
#   'date': '2019-01-06T04:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '1',
#   'bike_north': '1',
#   'bike_south': '0',
#   'date': '2019-01-06T05:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '3',
#   'bike_north': '1',
#   'bike_south': '0',
#   'date': '2019-01-06T06:00:00.000',
#   'ped_north': '1',
#   'ped_south': '1'},
#  {'bgt_north_of_ne_70th_total': '12',
#   'bike_north': '2',
#   'bike_south': '4',
#   'date': '2019-01-06T07:00:00.000',
#   'ped_north': '3',
#   'ped_south': '3'},
#  {'bgt_north_of_ne_70th_total': '38',
#   'bike_north': '5',
#   'bike_south': '14',
#   'date': '2019-01-06T08:00:00.000',
#   'ped_north': '10',
#   'ped_south': '9'},
#  {'bgt_north_of_ne_70th_total': '69',
#   'bike_north': '5',
#   'bike_south': '24',
#   'date': '2019-01-06T09:00:00.000',
#   'ped_north': '20',
#   'ped_south': '20'},
#  {'bgt_north_of_ne_70th_total': '102',
#   'bike_north': '18',
#   'bike_south': '23',
#   'date': '2019-01-06T10:00:00.000',
#   'ped_north': '26',
#   'ped_south': '35'},
#  {'bgt_north_of_ne_70th_total': '121',
#   'bike_north': '31',
#   'bike_south': '28',
#   'date': '2019-01-06T11:00:00.000',
#   'ped_north': '32',
#   'ped_south': '30'},
#  {'bgt_north_of_ne_70th_total': '115',
#   'bike_north': '36',
#   'bike_south': '29',
#   'date': '2019-01-06T12:00:00.000',
#   'ped_north': '28',
#   'ped_south': '22'},
#  {'bgt_north_of_ne_70th_total': '101',
#   'bike_north': '36',
#   'bike_south': '37',
#   'date': '2019-01-06T13:00:00.000',
#   'ped_north': '14',
#   'ped_south': '14'},
#  {'bgt_north_of_ne_70th_total': '97',
#   'bike_north': '21',
#   'bike_south': '37',
#   'date': '2019-01-06T14:00:00.000',
#   'ped_north': '18',
#   'ped_south': '21'},
#  {'bgt_north_of_ne_70th_total': '80',
#   'bike_north': '20',
#   'bike_south': '13',
#   'date': '2019-01-06T15:00:00.000',
#   'ped_north': '25',
#   'ped_south': '22'},
#  {'bgt_north_of_ne_70th_total': '41',
#   'bike_north': '13',
#   'bike_south': '7',
#   'date': '2019-01-06T16:00:00.000',
#   'ped_north': '12',
#   'ped_south': '9'},
#  {'bgt_north_of_ne_70th_total': '16',
#   'bike_north': '4',
#   'bike_south': '1',
#   'date': '2019-01-06T17:00:00.000',
#   'ped_north': '6',
#   'ped_south': '5'},
#  {'bgt_north_of_ne_70th_total': '10',
#   'bike_north': '4',
#   'bike_south': '2',
#   'date': '2019-01-06T18:00:00.000',
#   'ped_north': '2',
#   'ped_south': '2'},
#  {'bgt_north_of_ne_70th_total': '4',
#   'bike_north': '1',
#   'bike_south': '1',
#   'date': '2019-01-06T19:00:00.000',
#   'ped_north': '2',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '3',
#   'bike_north': '0',
#   'bike_south': '3',
#   'date': '2019-01-06T20:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '0',
#   'bike_north': '0',
#   'bike_south': '0',
#   'date': '2019-01-06T21:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '1',
#   'bike_north': '0',
#   'bike_south': '1',
#   'date': '2019-01-06T22:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '0',
#   'bike_north': '0',
#   'bike_south': '0',
#   'date': '2019-01-06T23:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '1',
#   'bike_north': '1',
#   'bike_south': '0',
#   'date': '2019-01-07T00:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '1',
#   'bike_north': '1',
#   'bike_south': '0',
#   'date': '2019-01-07T01:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '0',
#   'bike_north': '0',
#   'bike_south': '0',
#   'date': '2019-01-07T02:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '0',
#   'bike_north': '0',
#   'bike_south': '0',
#   'date': '2019-01-07T03:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '2',
#   'bike_north': '2',
#   'bike_south': '0',
#   'date': '2019-01-07T04:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '11',
#   'bike_north': '9',
#   'bike_south': '1',
#   'date': '2019-01-07T05:00:00.000',
#   'ped_north': '0',
#   'ped_south': '1'},
#  {'bgt_north_of_ne_70th_total': '30',
#   'bike_north': '25',
#   'bike_south': '2',
#   'date': '2019-01-07T06:00:00.000',
#   'ped_north': '2',
#   'ped_south': '1'},
#  {'bgt_north_of_ne_70th_total': '66',
#   'bike_north': '45',
#   'bike_south': '7',
#   'date': '2019-01-07T07:00:00.000',
#   'ped_north': '8',
#   'ped_south': '6'},
#  {'bgt_north_of_ne_70th_total': '81',
#   'bike_north': '49',
#   'bike_south': '6',
#   'date': '2019-01-07T08:00:00.000',
#   'ped_north': '11',
#   'ped_south': '15'},
#  {'bgt_north_of_ne_70th_total': '68',
#   'bike_north': '31',
#   'bike_south': '10',
#   'date': '2019-01-07T09:00:00.000',
#   'ped_north': '10',
#   'ped_south': '17'},
#  {'bgt_north_of_ne_70th_total': '61',
#   'bike_north': '27',
#   'bike_south': '9',
#   'date': '2019-01-07T10:00:00.000',
#   'ped_north': '17',
#   'ped_south': '8'},
#  {'bgt_north_of_ne_70th_total': '27',
#   'bike_north': '3',
#   'bike_south': '8',
#   'date': '2019-01-07T11:00:00.000',
#   'ped_north': '5',
#   'ped_south': '11'},
#  {'bgt_north_of_ne_70th_total': '39',
#   'bike_north': '9',
#   'bike_south': '14',
#   'date': '2019-01-07T12:00:00.000',
#   'ped_north': '7',
#   'ped_south': '9'},
#  {'bgt_north_of_ne_70th_total': '51',
#   'bike_north': '19',
#   'bike_south': '16',
#   'date': '2019-01-07T13:00:00.000',
#   'ped_north': '8',
#   'ped_south': '8'},
#  {'bgt_north_of_ne_70th_total': '49',
#   'bike_north': '18',
#   'bike_south': '16',
#   'date': '2019-01-07T14:00:00.000',
#   'ped_north': '9',
#   'ped_south': '6'},
#  {'bgt_north_of_ne_70th_total': '77',
#   'bike_north': '14',
#   'bike_south': '34',
#   'date': '2019-01-07T15:00:00.000',
#   'ped_north': '14',
#   'ped_south': '15'},
#  {'bgt_north_of_ne_70th_total': '104',
#   'bike_north': '20',
#   'bike_south': '42',
#   'date': '2019-01-07T16:00:00.000',
#   'ped_north': '21',
#   'ped_south': '21'},
#  {'bgt_north_of_ne_70th_total': '78',
#   'bike_north': '6',
#   'bike_south': '64',
#   'date': '2019-01-07T17:00:00.000',
#   'ped_north': '4',
#   'ped_south': '4'},
#  {'bgt_north_of_ne_70th_total': '61',
#   'bike_north': '4',
#   'bike_south': '42',
#   'date': '2019-01-07T18:00:00.000',
#   'ped_north': '7',
#   'ped_south': '8'},
#  {'bgt_north_of_ne_70th_total': '17',
#   'bike_north': '2',
#   'bike_south': '13',
#   'date': '2019-01-07T19:00:00.000',
#   'ped_north': '1',
#   'ped_south': '1'},
#  {'bgt_north_of_ne_70th_total': '6',
#   'bike_north': '1',
#   'bike_south': '3',
#   'date': '2019-01-07T20:00:00.000',
#   'ped_north': '0',
#   'ped_south': '2'},
#  {'bgt_north_of_ne_70th_total': '3',
#   'bike_north': '1',
#   'bike_south': '0',
#   'date': '2019-01-07T21:00:00.000',
#   'ped_north': '2',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '3',
#   'bike_north': '1',
#   'bike_south': '2',
#   'date': '2019-01-07T22:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '1',
#   'bike_north': '0',
#   'bike_south': '1',
#   'date': '2019-01-07T23:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '1',
#   'bike_north': '0',
#   'bike_south': '1',
#   'date': '2019-01-08T00:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '3',
#   'bike_north': '2',
#   'bike_south': '0',
#   'date': '2019-01-08T01:00:00.000',
#   'ped_north': '1',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '1',
#   'bike_north': '0',
#   'bike_south': '0',
#   'date': '2019-01-08T02:00:00.000',
#   'ped_north': '0',
#   'ped_south': '1'},
#  {'bgt_north_of_ne_70th_total': '1',
#   'bike_north': '0',
#   'bike_south': '1',
#   'date': '2019-01-08T03:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '3',
#   'bike_north': '2',
#   'bike_south': '1',
#   'date': '2019-01-08T04:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '9',
#   'bike_north': '7',
#   'bike_south': '0',
#   'date': '2019-01-08T05:00:00.000',
#   'ped_north': '2',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '28',
#   'bike_north': '20',
#   'bike_south': '4',
#   'date': '2019-01-08T06:00:00.000',
#   'ped_north': '1',
#   'ped_south': '3'},
#  {'bgt_north_of_ne_70th_total': '52',
#   'bike_north': '31',
#   'bike_south': '5',
#   'date': '2019-01-08T07:00:00.000',
#   'ped_north': '7',
#   'ped_south': '9'},
#  {'bgt_north_of_ne_70th_total': '71',
#   'bike_north': '40',
#   'bike_south': '4',
#   'date': '2019-01-08T08:00:00.000',
#   'ped_north': '17',
#   'ped_south': '10'},
#  {'bgt_north_of_ne_70th_total': '36',
#   'bike_north': '12',
#   'bike_south': '4',
#   'date': '2019-01-08T09:00:00.000',
#   'ped_north': '11',
#   'ped_south': '9'},
#  {'bgt_north_of_ne_70th_total': '14',
#   'bike_north': '3',
#   'bike_south': '0',
#   'date': '2019-01-08T10:00:00.000',
#   'ped_north': '6',
#   'ped_south': '5'},
#  {'bgt_north_of_ne_70th_total': '16',
#   'bike_north': '2',
#   'bike_south': '4',
#   'date': '2019-01-08T11:00:00.000',
#   'ped_north': '5',
#   'ped_south': '5'},
#  {'bgt_north_of_ne_70th_total': '18',
#   'bike_north': '5',
#   'bike_south': '2',
#   'date': '2019-01-08T12:00:00.000',
#   'ped_north': '5',
#   'ped_south': '6'},
#  {'bgt_north_of_ne_70th_total': '18',
#   'bike_north': '5',
#   'bike_south': '3',
#   'date': '2019-01-08T13:00:00.000',
#   'ped_north': '7',
#   'ped_south': '3'},
#  {'bgt_north_of_ne_70th_total': '29',
#   'bike_north': '6',
#   'bike_south': '8',
#   'date': '2019-01-08T14:00:00.000',
#   'ped_north': '6',
#   'ped_south': '9'},
#  {'bgt_north_of_ne_70th_total': '36',
#   'bike_north': '1',
#   'bike_south': '12',
#   'date': '2019-01-08T15:00:00.000',
#   'ped_north': '8',
#   'ped_south': '15'},
#  {'bgt_north_of_ne_70th_total': '58',
#   'bike_north': '7',
#   'bike_south': '27',
#   'date': '2019-01-08T16:00:00.000',
#   'ped_north': '14',
#   'ped_south': '10'},
#  {'bgt_north_of_ne_70th_total': '62',
#   'bike_north': '9',
#   'bike_south': '41',
#   'date': '2019-01-08T17:00:00.000',
#   'ped_north': '5',
#   'ped_south': '7'},
#  {'bgt_north_of_ne_70th_total': '49',
#   'bike_north': '6',
#   'bike_south': '36',
#   'date': '2019-01-08T18:00:00.000',
#   'ped_north': '4',
#   'ped_south': '3'},
#  {'bgt_north_of_ne_70th_total': '26',
#   'bike_north': '1',
#   'bike_south': '15',
#   'date': '2019-01-08T19:00:00.000',
#   'ped_north': '7',
#   'ped_south': '3'},
#  {'bgt_north_of_ne_70th_total': '5',
#   'bike_north': '0',
#   'bike_south': '5',
#   'date': '2019-01-08T20:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '3',
#   'bike_north': '3',
#   'bike_south': '0',
#   'date': '2019-01-08T21:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '4',
#   'bike_north': '0',
#   'bike_south': '4',
#   'date': '2019-01-08T22:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '0',
#   'bike_north': '0',
#   'bike_south': '0',
#   'date': '2019-01-08T23:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '1',
#   'bike_north': '0',
#   'bike_south': '0',
#   'date': '2019-01-09T00:00:00.000',
#   'ped_north': '1',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '0',
#   'bike_north': '0',
#   'bike_south': '0',
#   'date': '2019-01-09T01:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '1',
#   'bike_north': '0',
#   'bike_south': '1',
#   'date': '2019-01-09T02:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '1',
#   'bike_north': '0',
#   'bike_south': '0',
#   'date': '2019-01-09T03:00:00.000',
#   'ped_north': '0',
#   'ped_south': '1'},
#  {'bgt_north_of_ne_70th_total': '2',
#   'bike_north': '2',
#   'bike_south': '0',
#   'date': '2019-01-09T04:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '11',
#   'bike_north': '9',
#   'bike_south': '0',
#   'date': '2019-01-09T05:00:00.000',
#   'ped_north': '2',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '45',
#   'bike_north': '15',
#   'bike_south': '2',
#   'date': '2019-01-09T06:00:00.000',
#   'ped_north': '15',
#   'ped_south': '13'},
#  {'bgt_north_of_ne_70th_total': '42',
#   'bike_north': '33',
#   'bike_south': '1',
#   'date': '2019-01-09T07:00:00.000',
#   'ped_north': '4',
#   'ped_south': '4'},
#  {'bgt_north_of_ne_70th_total': '72',
#   'bike_north': '40',
#   'bike_south': '6',
#   'date': '2019-01-09T08:00:00.000',
#   'ped_north': '14',
#   'ped_south': '12'},
#  {'bgt_north_of_ne_70th_total': '43',
#   'bike_north': '19',
#   'bike_south': '6',
#   'date': '2019-01-09T09:00:00.000',
#   'ped_north': '10',
#   'ped_south': '8'},
#  {'bgt_north_of_ne_70th_total': '40',
#   'bike_north': '13',
#   'bike_south': '7',
#   'date': '2019-01-09T10:00:00.000',
#   'ped_north': '11',
#   'ped_south': '9'},
#  {'bgt_north_of_ne_70th_total': '28',
#   'bike_north': '6',
#   'bike_south': '5',
#   'date': '2019-01-09T11:00:00.000',
#   'ped_north': '8',
#   'ped_south': '9'},
#  {'bgt_north_of_ne_70th_total': '34',
#   'bike_north': '5',
#   'bike_south': '8',
#   'date': '2019-01-09T12:00:00.000',
#   'ped_north': '11',
#   'ped_south': '10'},
#  {'bgt_north_of_ne_70th_total': '32',
#   'bike_north': '6',
#   'bike_south': '12',
#   'date': '2019-01-09T13:00:00.000',
#   'ped_north': '9',
#   'ped_south': '5'},
#  {'bgt_north_of_ne_70th_total': '25',
#   'bike_north': '2',
#   'bike_south': '10',
#   'date': '2019-01-09T14:00:00.000',
#   'ped_north': '5',
#   'ped_south': '8'},
#  {'bgt_north_of_ne_70th_total': '24',
#   'bike_north': '2',
#   'bike_south': '8',
#   'date': '2019-01-09T15:00:00.000',
#   'ped_north': '5',
#   'ped_south': '9'},
#  {'bgt_north_of_ne_70th_total': '57',
#   'bike_north': '10',
#   'bike_south': '20',
#   'date': '2019-01-09T16:00:00.000',
#   'ped_north': '14',
#   'ped_south': '13'},
#  {'bgt_north_of_ne_70th_total': '58',
#   'bike_north': '4',
#   'bike_south': '42',
#   'date': '2019-01-09T17:00:00.000',
#   'ped_north': '6',
#   'ped_south': '6'},
#  {'bgt_north_of_ne_70th_total': '41',
#   'bike_north': '4',
#   'bike_south': '31',
#   'date': '2019-01-09T18:00:00.000',
#   'ped_north': '4',
#   'ped_south': '2'},
#  {'bgt_north_of_ne_70th_total': '23',
#   'bike_north': '2',
#   'bike_south': '16',
#   'date': '2019-01-09T19:00:00.000',
#   'ped_north': '2',
#   'ped_south': '3'},
#  {'bgt_north_of_ne_70th_total': '6',
#   'bike_north': '0',
#   'bike_south': '4',
#   'date': '2019-01-09T20:00:00.000',
#   'ped_north': '0',
#   'ped_south': '2'},
#  {'bgt_north_of_ne_70th_total': '7',
#   'bike_north': '1',
#   'bike_south': '2',
#   'date': '2019-01-09T21:00:00.000',
#   'ped_north': '2',
#   'ped_south': '2'},
#  {'bgt_north_of_ne_70th_total': '3',
#   'bike_north': '1',
#   'bike_south': '2',
#   'date': '2019-01-09T22:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '2',
#   'bike_north': '0',
#   'bike_south': '1',
#   'date': '2019-01-09T23:00:00.000',
#   'ped_north': '1',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '0',
#   'bike_north': '0',
#   'bike_south': '0',
#   'date': '2019-01-10T00:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '0',
#   'bike_north': '0',
#   'bike_south': '0',
#   'date': '2019-01-10T01:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '0',
#   'bike_north': '0',
#   'bike_south': '0',
#   'date': '2019-01-10T02:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '0',
#   'bike_north': '0',
#   'bike_south': '0',
#   'date': '2019-01-10T03:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '3',
#   'bike_north': '2',
#   'bike_south': '1',
#   'date': '2019-01-10T04:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '15',
#   'bike_north': '12',
#   'bike_south': '2',
#   'date': '2019-01-10T05:00:00.000',
#   'ped_north': '0',
#   'ped_south': '1'},
#  {'bgt_north_of_ne_70th_total': '33',
#   'bike_north': '21',
#   'bike_south': '2',
#   'date': '2019-01-10T06:00:00.000',
#   'ped_north': '5',
#   'ped_south': '5'},
#  {'bgt_north_of_ne_70th_total': '64',
#   'bike_north': '45',
#   'bike_south': '4',
#   'date': '2019-01-10T07:00:00.000',
#   'ped_north': '8',
#   'ped_south': '7'},
#  {'bgt_north_of_ne_70th_total': '85',
#   'bike_north': '48',
#   'bike_south': '9',
#   'date': '2019-01-10T08:00:00.000',
#   'ped_north': '14',
#   'ped_south': '14'},
#  {'bgt_north_of_ne_70th_total': '45',
#   'bike_north': '20',
#   'bike_south': '5',
#   'date': '2019-01-10T09:00:00.000',
#   'ped_north': '12',
#   'ped_south': '8'},
#  {'bgt_north_of_ne_70th_total': '45',
#   'bike_north': '11',
#   'bike_south': '8',
#   'date': '2019-01-10T10:00:00.000',
#   'ped_north': '16',
#   'ped_south': '10'},
#  {'bgt_north_of_ne_70th_total': '30',
#   'bike_north': '6',
#   'bike_south': '10',
#   'date': '2019-01-10T11:00:00.000',
#   'ped_north': '7',
#   'ped_south': '7'},
#  {'bgt_north_of_ne_70th_total': '42',
#   'bike_north': '8',
#   'bike_south': '12',
#   'date': '2019-01-10T12:00:00.000',
#   'ped_north': '8',
#   'ped_south': '14'},
#  {'bgt_north_of_ne_70th_total': '32',
#   'bike_north': '9',
#   'bike_south': '6',
#   'date': '2019-01-10T13:00:00.000',
#   'ped_north': '10',
#   'ped_south': '7'},
#  {'bgt_north_of_ne_70th_total': '42',
#   'bike_north': '4',
#   'bike_south': '14',
#   'date': '2019-01-10T14:00:00.000',
#   'ped_north': '15',
#   'ped_south': '9'},
#  {'bgt_north_of_ne_70th_total': '42',
#   'bike_north': '2',
#   'bike_south': '19',
#   'date': '2019-01-10T15:00:00.000',
#   'ped_north': '9',
#   'ped_south': '12'},
#  {'bgt_north_of_ne_70th_total': '84',
#   'bike_north': '18',
#   'bike_south': '37',
#   'date': '2019-01-10T16:00:00.000',
#   'ped_north': '16',
#   'ped_south': '13'},
#  {'bgt_north_of_ne_70th_total': '97',
#   'bike_north': '12',
#   'bike_south': '63',
#   'date': '2019-01-10T17:00:00.000',
#   'ped_north': '10',
#   'ped_south': '12'},
#  {'bgt_north_of_ne_70th_total': '50',
#   'bike_north': '6',
#   'bike_south': '31',
#   'date': '2019-01-10T18:00:00.000',
#   'ped_north': '0',
#   'ped_south': '13'},
#  {'bgt_north_of_ne_70th_total': '25',
#   'bike_north': '2',
#   'bike_south': '18',
#   'date': '2019-01-10T19:00:00.000',
#   'ped_north': '3',
#   'ped_south': '2'},
#  {'bgt_north_of_ne_70th_total': '23',
#   'bike_north': '1',
#   'bike_south': '10',
#   'date': '2019-01-10T20:00:00.000',
#   'ped_north': '11',
#   'ped_south': '1'},
#  {'bgt_north_of_ne_70th_total': '10',
#   'bike_north': '4',
#   'bike_south': '5',
#   'date': '2019-01-10T21:00:00.000',
#   'ped_north': '0',
#   'ped_south': '1'},
#  {'bgt_north_of_ne_70th_total': '1',
#   'bike_north': '1',
#   'bike_south': '0',
#   'date': '2019-01-10T22:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '0',
#   'bike_north': '0',
#   'bike_south': '0',
#   'date': '2019-01-10T23:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '3',
#   'bike_north': '2',
#   'bike_south': '0',
#   'date': '2019-01-11T00:00:00.000',
#   'ped_north': '0',
#   'ped_south': '1'},
#  {'bgt_north_of_ne_70th_total': '0',
#   'bike_north': '0',
#   'bike_south': '0',
#   'date': '2019-01-11T01:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '0',
#   'bike_north': '0',
#   'bike_south': '0',
#   'date': '2019-01-11T02:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '0',
#   'bike_north': '0',
#   'bike_south': '0',
#   'date': '2019-01-11T03:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '3',
#   'bike_north': '1',
#   'bike_south': '2',
#   'date': '2019-01-11T04:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '10',
#   'bike_north': '5',
#   'bike_south': '1',
#   'date': '2019-01-11T05:00:00.000',
#   'ped_north': '2',
#   'ped_south': '2'},
#  {'bgt_north_of_ne_70th_total': '33',
#   'bike_north': '22',
#   'bike_south': '3',
#   'date': '2019-01-11T06:00:00.000',
#   'ped_north': '4',
#   'ped_south': '4'},
#  {'bgt_north_of_ne_70th_total': '52',
#   'bike_north': '28',
#   'bike_south': '10',
#   'date': '2019-01-11T07:00:00.000',
#   'ped_north': '7',
#   'ped_south': '7'},
#  {'bgt_north_of_ne_70th_total': '90',
#   'bike_north': '54',
#   'bike_south': '8',
#   'date': '2019-01-11T08:00:00.000',
#   'ped_north': '12',
#   'ped_south': '16'},
#  {'bgt_north_of_ne_70th_total': '80',
#   'bike_north': '33',
#   'bike_south': '14',
#   'date': '2019-01-11T09:00:00.000',
#   'ped_north': '18',
#   'ped_south': '15'},
#  {'bgt_north_of_ne_70th_total': '38',
#   'bike_north': '13',
#   'bike_south': '5',
#   'date': '2019-01-11T10:00:00.000',
#   'ped_north': '9',
#   'ped_south': '11'},
#  {'bgt_north_of_ne_70th_total': '58',
#   'bike_north': '20',
#   'bike_south': '17',
#   'date': '2019-01-11T11:00:00.000',
#   'ped_north': '10',
#   'ped_south': '11'},
#  {'bgt_north_of_ne_70th_total': '72',
#   'bike_north': '22',
#   'bike_south': '23',
#   'date': '2019-01-11T12:00:00.000',
#   'ped_north': '14',
#   'ped_south': '13'},
#  {'bgt_north_of_ne_70th_total': '53',
#   'bike_north': '16',
#   'bike_south': '20',
#   'date': '2019-01-11T13:00:00.000',
#   'ped_north': '9',
#   'ped_south': '8'},
#  {'bgt_north_of_ne_70th_total': '71',
#   'bike_north': '33',
#   'bike_south': '24',
#   'date': '2019-01-11T14:00:00.000',
#   'ped_north': '10',
#   'ped_south': '4'},
#  {'bgt_north_of_ne_70th_total': '91',
#   'bike_north': '19',
#   'bike_south': '47',
#   'date': '2019-01-11T15:00:00.000',
#   'ped_north': '9',
#   'ped_south': '16'},
#  {'bgt_north_of_ne_70th_total': '94',
#   'bike_north': '31',
#   'bike_south': '39',
#   'date': '2019-01-11T16:00:00.000',
#   'ped_north': '16',
#   'ped_south': '8'},
#  {'bgt_north_of_ne_70th_total': '80',
#   'bike_north': '14',
#   'bike_south': '53',
#   'date': '2019-01-11T17:00:00.000',
#   'ped_north': '7',
#   'ped_south': '6'},
#  {'bgt_north_of_ne_70th_total': '35',
#   'bike_north': '4',
#   'bike_south': '27',
#   'date': '2019-01-11T18:00:00.000',
#   'ped_north': '2',
#   'ped_south': '2'},
#  {'bgt_north_of_ne_70th_total': '25',
#   'bike_north': '1',
#   'bike_south': '16',
#   'date': '2019-01-11T19:00:00.000',
#   'ped_north': '3',
#   'ped_south': '5'},
#  {'bgt_north_of_ne_70th_total': '8',
#   'bike_north': '0',
#   'bike_south': '8',
#   'date': '2019-01-11T20:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '7',
#   'bike_north': '0',
#   'bike_south': '6',
#   'date': '2019-01-11T21:00:00.000',
#   'ped_north': '0',
#   'ped_south': '1'},
#  {'bgt_north_of_ne_70th_total': '1',
#   'bike_north': '0',
#   'bike_south': '0',
#   'date': '2019-01-11T22:00:00.000',
#   'ped_north': '1',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '1',
#   'bike_north': '0',
#   'bike_south': '0',
#   'date': '2019-01-11T23:00:00.000',
#   'ped_north': '0',
#   'ped_south': '1'},
#  {'bgt_north_of_ne_70th_total': '2',
#   'bike_north': '0',
#   'bike_south': '1',
#   'date': '2019-01-12T00:00:00.000',
#   'ped_north': '1',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '0',
#   'bike_north': '0',
#   'bike_south': '0',
#   'date': '2019-01-12T01:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '0',
#   'bike_north': '0',
#   'bike_south': '0',
#   'date': '2019-01-12T02:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '0',
#   'bike_north': '0',
#   'bike_south': '0',
#   'date': '2019-01-12T03:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '0',
#   'bike_north': '0',
#   'bike_south': '0',
#   'date': '2019-01-12T04:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '7',
#   'bike_north': '4',
#   'bike_south': '1',
#   'date': '2019-01-12T05:00:00.000',
#   'ped_north': '1',
#   'ped_south': '1'},
#  {'bgt_north_of_ne_70th_total': '6',
#   'bike_north': '2',
#   'bike_south': '3',
#   'date': '2019-01-12T06:00:00.000',
#   'ped_north': '0',
#   'ped_south': '1'},
#  {'bgt_north_of_ne_70th_total': '33',
#   'bike_north': '11',
#   'bike_south': '11',
#   'date': '2019-01-12T07:00:00.000',
#   'ped_north': '5',
#   'ped_south': '6'},
#  {'bgt_north_of_ne_70th_total': '79',
#   'bike_north': '10',
#   'bike_south': '35',
#   'date': '2019-01-12T08:00:00.000',
#   'ped_north': '19',
#   'ped_south': '15'},
#  {'bgt_north_of_ne_70th_total': '109',
#   'bike_north': '27',
#   'bike_south': '36',
#   'date': '2019-01-12T09:00:00.000',
#   'ped_north': '21',
#   'ped_south': '25'},
#  {'bgt_north_of_ne_70th_total': '173',
#   'bike_north': '43',
#   'bike_south': '73',
#   'date': '2019-01-12T10:00:00.000',
#   'ped_north': '28',
#   'ped_south': '29'},
#  {'bgt_north_of_ne_70th_total': '238',
#   'bike_north': '72',
#   'bike_south': '97',
#   'date': '2019-01-12T11:00:00.000',
#   'ped_north': '35',
#   'ped_south': '34'},
#  {'bgt_north_of_ne_70th_total': '204',
#   'bike_north': '77',
#   'bike_south': '68',
#   'date': '2019-01-12T12:00:00.000',
#   'ped_north': '33',
#   'ped_south': '26'},
#  {'bgt_north_of_ne_70th_total': '242',
#   'bike_north': '87',
#   'bike_south': '103',
#   'date': '2019-01-12T13:00:00.000',
#   'ped_north': '26',
#   'ped_south': '26'},
#  {'bgt_north_of_ne_70th_total': '245',
#   'bike_north': '89',
#   'bike_south': '93',
#   'date': '2019-01-12T14:00:00.000',
#   'ped_north': '33',
#   'ped_south': '30'},
#  {'bgt_north_of_ne_70th_total': '225',
#   'bike_north': '86',
#   'bike_south': '83',
#   'date': '2019-01-12T15:00:00.000',
#   'ped_north': '30',
#   'ped_south': '26'},
#  {'bgt_north_of_ne_70th_total': '139',
#   'bike_north': '64',
#   'bike_south': '43',
#   'date': '2019-01-12T16:00:00.000',
#   'ped_north': '19',
#   'ped_south': '13'},
#  {'bgt_north_of_ne_70th_total': '35',
#   'bike_north': '13',
#   'bike_south': '10',
#   'date': '2019-01-12T17:00:00.000',
#   'ped_north': '7',
#   'ped_south': '5'},
#  {'bgt_north_of_ne_70th_total': '6',
#   'bike_north': '2',
#   'bike_south': '2',
#   'date': '2019-01-12T18:00:00.000',
#   'ped_north': '1',
#   'ped_south': '1'},
#  {'bgt_north_of_ne_70th_total': '10',
#   'bike_north': '1',
#   'bike_south': '3',
#   'date': '2019-01-12T19:00:00.000',
#   'ped_north': '5',
#   'ped_south': '1'},
#  {'bgt_north_of_ne_70th_total': '1',
#   'bike_north': '0',
#   'bike_south': '1',
#   'date': '2019-01-12T20:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '4',
#   'bike_north': '0',
#   'bike_south': '1',
#   'date': '2019-01-12T21:00:00.000',
#   'ped_north': '1',
#   'ped_south': '2'},
#  {'bgt_north_of_ne_70th_total': '1',
#   'bike_north': '0',
#   'bike_south': '1',
#   'date': '2019-01-12T22:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '0',
#   'bike_north': '0',
#   'bike_south': '0',
#   'date': '2019-01-12T23:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '0',
#   'bike_north': '0',
#   'bike_south': '0',
#   'date': '2019-01-13T00:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '0',
#   'bike_north': '0',
#   'bike_south': '0',
#   'date': '2019-01-13T01:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '1',
#   'bike_north': '0',
#   'bike_south': '1',
#   'date': '2019-01-13T02:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '0',
#   'bike_north': '0',
#   'bike_south': '0',
#   'date': '2019-01-13T03:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '1',
#   'bike_north': '1',
#   'bike_south': '0',
#   'date': '2019-01-13T04:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '3',
#   'bike_north': '3',
#   'bike_south': '0',
#   'date': '2019-01-13T05:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '3',
#   'bike_north': '1',
#   'bike_south': '0',
#   'date': '2019-01-13T06:00:00.000',
#   'ped_north': '2',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '18',
#   'bike_north': '2',
#   'bike_south': '7',
#   'date': '2019-01-13T07:00:00.000',
#   'ped_north': '1',
#   'ped_south': '8'},
#  {'bgt_north_of_ne_70th_total': '31',
#   'bike_north': '4',
#   'bike_south': '7',
#   'date': '2019-01-13T08:00:00.000',
#   'ped_north': '11',
#   'ped_south': '9'},
#  {'bgt_north_of_ne_70th_total': '97',
#   'bike_north': '16',
#   'bike_south': '29',
#   'date': '2019-01-13T09:00:00.000',
#   'ped_north': '23',
#   'ped_south': '29'},
#  {'bgt_north_of_ne_70th_total': '138',
#   'bike_north': '25',
#   'bike_south': '51',
#   'date': '2019-01-13T10:00:00.000',
#   'ped_north': '32',
#   'ped_south': '30'},
#  {'bgt_north_of_ne_70th_total': '162',
#   'bike_north': '55',
#   'bike_south': '61',
#   'date': '2019-01-13T11:00:00.000',
#   'ped_north': '27',
#   'ped_south': '19'},
#  {'bgt_north_of_ne_70th_total': '174',
#   'bike_north': '66',
#   'bike_south': '59',
#   'date': '2019-01-13T12:00:00.000',
#   'ped_north': '16',
#   'ped_south': '33'},
#  {'bgt_north_of_ne_70th_total': '262',
#   'bike_north': '83',
#   'bike_south': '120',
#   'date': '2019-01-13T13:00:00.000',
#   'ped_north': '30',
#   'ped_south': '29'},
#  {'bgt_north_of_ne_70th_total': '285',
#   'bike_north': '100',
#   'bike_south': '125',
#   'date': '2019-01-13T14:00:00.000',
#   'ped_north': '35',
#   'ped_south': '25'},
# ...
#   'bike_north': '0',
#   'bike_south': '7',
#   'date': '2019-12-27T19:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '4',
#   'bike_north': '2',
#   'bike_south': '2',
#   'date': '2019-12-27T20:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '0',
#   'bike_north': '0',
#   'bike_south': '0',
#   'date': '2019-12-27T21:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '6',
#   'bike_north': '1',
#   'bike_south': '3',
#   'date': '2019-12-27T22:00:00.000',
#   'ped_north': '1',
#   'ped_south': '1'},
#  {'bgt_north_of_ne_70th_total': '0',
#   'bike_north': '0',
#   'bike_south': '0',
#   'date': '2019-12-27T23:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '5',
#   'bike_north': '1',
#   'bike_south': '0',
#   'date': '2019-12-28T00:00:00.000',
#   'ped_north': '2',
#   'ped_south': '2'},
#  {'bgt_north_of_ne_70th_total': '0',
#   'bike_north': '0',
#   'bike_south': '0',
#   'date': '2019-12-28T01:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '0',
#   'bike_north': '0',
#   'bike_south': '0',
#   'date': '2019-12-28T02:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '0',
#   'bike_north': '0',
#   'bike_south': '0',
#   'date': '2019-12-28T03:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '3',
#   'bike_north': '0',
#   'bike_south': '3',
#   'date': '2019-12-28T04:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '1',
#   'bike_north': '0',
#   'bike_south': '1',
#   'date': '2019-12-28T05:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '6',
#   'bike_north': '2',
#   'bike_south': '2',
#   'date': '2019-12-28T06:00:00.000',
#   'ped_north': '1',
#   'ped_south': '1'},
#  {'bgt_north_of_ne_70th_total': '13',
#   'bike_north': '1',
#   'bike_south': '4',
#   'date': '2019-12-28T07:00:00.000',
#   'ped_north': '3',
#   'ped_south': '5'},
#  {'bgt_north_of_ne_70th_total': '70',
#   'bike_north': '8',
#   'bike_south': '24',
#   'date': '2019-12-28T08:00:00.000',
#   'ped_north': '21',
#   'ped_south': '17'},
#  {'bgt_north_of_ne_70th_total': '72',
#   'bike_north': '15',
#   'bike_south': '25',
#   'date': '2019-12-28T09:00:00.000',
#   'ped_north': '14',
#   'ped_south': '18'},
#  {'bgt_north_of_ne_70th_total': '90',
#   'bike_north': '18',
#   'bike_south': '23',
#   'date': '2019-12-28T10:00:00.000',
#   'ped_north': '24',
#   'ped_south': '25'},
#  {'bgt_north_of_ne_70th_total': '121',
#   'bike_north': '42',
#   'bike_south': '29',
#   'date': '2019-12-28T11:00:00.000',
#   'ped_north': '25',
#   'ped_south': '25'},
#  {'bgt_north_of_ne_70th_total': '141',
#   'bike_north': '44',
#   'bike_south': '42',
#   'date': '2019-12-28T12:00:00.000',
#   'ped_north': '26',
#   'ped_south': '29'},
#  {'bgt_north_of_ne_70th_total': '129',
#   'bike_north': '51',
#   'bike_south': '46',
#   'date': '2019-12-28T13:00:00.000',
#   'ped_north': '20',
#   'ped_south': '12'},
#  {'bgt_north_of_ne_70th_total': '101',
#   'bike_north': '44',
#   'bike_south': '25',
#   'date': '2019-12-28T14:00:00.000',
#   'ped_north': '17',
#   'ped_south': '15'},
#  {'bgt_north_of_ne_70th_total': '60',
#   'bike_north': '19',
#   'bike_south': '22',
#   'date': '2019-12-28T15:00:00.000',
#   'ped_north': '7',
#   'ped_south': '12'},
#  {'bgt_north_of_ne_70th_total': '39',
#   'bike_north': '14',
#   'bike_south': '6',
#   'date': '2019-12-28T16:00:00.000',
#   'ped_north': '9',
#   'ped_south': '10'},
#  {'bgt_north_of_ne_70th_total': '23',
#   'bike_north': '11',
#   'bike_south': '2',
#   'date': '2019-12-28T17:00:00.000',
#   'ped_north': '7',
#   'ped_south': '3'},
#  {'bgt_north_of_ne_70th_total': '1',
#   'bike_north': '0',
#   'bike_south': '1',
#   'date': '2019-12-28T18:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '1',
#   'bike_north': '0',
#   'bike_south': '1',
#   'date': '2019-12-28T19:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '2',
#   'bike_north': '0',
#   'bike_south': '0',
#   'date': '2019-12-28T20:00:00.000',
#   'ped_north': '1',
#   'ped_south': '1'},
#  {'bgt_north_of_ne_70th_total': '1',
#   'bike_north': '0',
#   'bike_south': '1',
#   'date': '2019-12-28T21:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '0',
#   'bike_north': '0',
#   'bike_south': '0',
#   'date': '2019-12-28T22:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '2',
#   'bike_north': '0',
#   'bike_south': '0',
#   'date': '2019-12-28T23:00:00.000',
#   'ped_north': '1',
#   'ped_south': '1'},
#  {'bgt_north_of_ne_70th_total': '4',
#   'bike_north': '2',
#   'bike_south': '1',
#   'date': '2019-12-29T00:00:00.000',
#   'ped_north': '0',
#   'ped_south': '1'},
#  {'bgt_north_of_ne_70th_total': '1',
#   'bike_north': '0',
#   'bike_south': '0',
#   'date': '2019-12-29T01:00:00.000',
#   'ped_north': '1',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '0',
#   'bike_north': '0',
#   'bike_south': '0',
#   'date': '2019-12-29T02:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '1',
#   'bike_north': '0',
#   'bike_south': '1',
#   'date': '2019-12-29T03:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '0',
#   'bike_north': '0',
#   'bike_south': '0',
#   'date': '2019-12-29T04:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '0',
#   'bike_north': '0',
#   'bike_south': '0',
#   'date': '2019-12-29T05:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '3',
#   'bike_north': '0',
#   'bike_south': '0',
#   'date': '2019-12-29T06:00:00.000',
#   'ped_north': '2',
#   'ped_south': '1'},
#  {'bgt_north_of_ne_70th_total': '7',
#   'bike_north': '0',
#   'bike_south': '2',
#   'date': '2019-12-29T07:00:00.000',
#   'ped_north': '2',
#   'ped_south': '3'},
#  {'bgt_north_of_ne_70th_total': '40',
#   'bike_north': '4',
#   'bike_south': '9',
#   'date': '2019-12-29T08:00:00.000',
#   'ped_north': '8',
#   'ped_south': '19'},
#  {'bgt_north_of_ne_70th_total': '73',
#   'bike_north': '13',
#   'bike_south': '15',
#   'date': '2019-12-29T09:00:00.000',
#   'ped_north': '23',
#   'ped_south': '22'},
#  {'bgt_north_of_ne_70th_total': '113',
#   'bike_north': '26',
#   'bike_south': '26',
#   'date': '2019-12-29T10:00:00.000',
#   'ped_north': '33',
#   'ped_south': '28'},
#  {'bgt_north_of_ne_70th_total': '110',
#   'bike_north': '29',
#   'bike_south': '44',
#   'date': '2019-12-29T11:00:00.000',
#   'ped_north': '20',
#   'ped_south': '17'},
#  {'bgt_north_of_ne_70th_total': '130',
#   'bike_north': '40',
#   'bike_south': '51',
#   'date': '2019-12-29T12:00:00.000',
#   'ped_north': '20',
#   'ped_south': '19'},
#  {'bgt_north_of_ne_70th_total': '155',
#   'bike_north': '56',
#   'bike_south': '55',
#   'date': '2019-12-29T13:00:00.000',
#   'ped_north': '24',
#   'ped_south': '20'},
#  {'bgt_north_of_ne_70th_total': '167',
#   'bike_north': '47',
#   'bike_south': '65',
#   'date': '2019-12-29T14:00:00.000',
#   'ped_north': '33',
#   'ped_south': '22'},
#  {'bgt_north_of_ne_70th_total': '132',
#   'bike_north': '62',
#   'bike_south': '37',
#   'date': '2019-12-29T15:00:00.000',
#   'ped_north': '16',
#   'ped_south': '17'},
#  {'bgt_north_of_ne_70th_total': '64',
#   'bike_north': '20',
#   'bike_south': '18',
#   'date': '2019-12-29T16:00:00.000',
#   'ped_north': '16',
#   'ped_south': '10'},
#  {'bgt_north_of_ne_70th_total': '16',
#   'bike_north': '4',
#   'bike_south': '4',
#   'date': '2019-12-29T17:00:00.000',
#   'ped_north': '4',
#   'ped_south': '4'},
#  {'bgt_north_of_ne_70th_total': '10',
#   'bike_north': '2',
#   'bike_south': '1',
#   'date': '2019-12-29T18:00:00.000',
#   'ped_north': '3',
#   'ped_south': '4'},
#  {'bgt_north_of_ne_70th_total': '2',
#   'bike_north': '1',
#   'bike_south': '1',
#   'date': '2019-12-29T19:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '6',
#   'bike_north': '0',
#   'bike_south': '0',
#   'date': '2019-12-29T20:00:00.000',
#   'ped_north': '3',
#   'ped_south': '3'},
#  {'bgt_north_of_ne_70th_total': '2',
#   'bike_north': '0',
#   'bike_south': '2',
#   'date': '2019-12-29T21:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '1',
#   'bike_north': '0',
#   'bike_south': '1',
#   'date': '2019-12-29T22:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '2',
#   'bike_north': '0',
#   'bike_south': '0',
#   'date': '2019-12-29T23:00:00.000',
#   'ped_north': '1',
#   'ped_south': '1'},
#  {'bgt_north_of_ne_70th_total': '2',
#   'bike_north': '0',
#   'bike_south': '0',
#   'date': '2019-12-30T00:00:00.000',
#   'ped_north': '1',
#   'ped_south': '1'},
#  {'bgt_north_of_ne_70th_total': '0',
#   'bike_north': '0',
#   'bike_south': '0',
#   'date': '2019-12-30T01:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '1',
#   'bike_north': '0',
#   'bike_south': '0',
#   'date': '2019-12-30T02:00:00.000',
#   'ped_north': '0',
#   'ped_south': '1'},
#  {'bgt_north_of_ne_70th_total': '0',
#   'bike_north': '0',
#   'bike_south': '0',
#   'date': '2019-12-30T03:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '1',
#   'bike_north': '1',
#   'bike_south': '0',
#   'date': '2019-12-30T04:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '6',
#   'bike_north': '4',
#   'bike_south': '0',
#   'date': '2019-12-30T05:00:00.000',
#   'ped_north': '1',
#   'ped_south': '1'},
#  {'bgt_north_of_ne_70th_total': '23',
#   'bike_north': '17',
#   'bike_south': '0',
#   'date': '2019-12-30T06:00:00.000',
#   'ped_north': '4',
#   'ped_south': '2'},
#  {'bgt_north_of_ne_70th_total': '31',
#   'bike_north': '19',
#   'bike_south': '4',
#   'date': '2019-12-30T07:00:00.000',
#   'ped_north': '5',
#   'ped_south': '3'},
#  {'bgt_north_of_ne_70th_total': '53',
#   'bike_north': '22',
#   'bike_south': '7',
#   'date': '2019-12-30T08:00:00.000',
#   'ped_north': '10',
#   'ped_south': '14'},
#  {'bgt_north_of_ne_70th_total': '43',
#   'bike_north': '16',
#   'bike_south': '12',
#   'date': '2019-12-30T09:00:00.000',
#   'ped_north': '7',
#   'ped_south': '8'},
#  {'bgt_north_of_ne_70th_total': '73',
#   'bike_north': '31',
#   'bike_south': '11',
#   'date': '2019-12-30T10:00:00.000',
#   'ped_north': '17',
#   'ped_south': '14'},
#  {'bgt_north_of_ne_70th_total': '43',
#   'bike_north': '17',
#   'bike_south': '13',
#   'date': '2019-12-30T11:00:00.000',
#   'ped_north': '9',
#   'ped_south': '4'},
#  {'bgt_north_of_ne_70th_total': '42',
#   'bike_north': '9',
#   'bike_south': '21',
#   'date': '2019-12-30T12:00:00.000',
#   'ped_north': '4',
#   'ped_south': '8'},
#  {'bgt_north_of_ne_70th_total': '47',
#   'bike_north': '7',
#   'bike_south': '16',
#   'date': '2019-12-30T13:00:00.000',
#   'ped_north': '13',
#   'ped_south': '11'},
#  {'bgt_north_of_ne_70th_total': '45',
#   'bike_north': '14',
#   'bike_south': '15',
#   'date': '2019-12-30T14:00:00.000',
#   'ped_north': '7',
#   'ped_south': '9'},
#  {'bgt_north_of_ne_70th_total': '59',
#   'bike_north': '16',
#   'bike_south': '24',
#   'date': '2019-12-30T15:00:00.000',
#   'ped_north': '9',
#   'ped_south': '10'},
#  {'bgt_north_of_ne_70th_total': '71',
#   'bike_north': '12',
#   'bike_south': '28',
#   'date': '2019-12-30T16:00:00.000',
#   'ped_north': '14',
#   'ped_south': '17'},
#  {'bgt_north_of_ne_70th_total': '52',
#   'bike_north': '4',
#   'bike_south': '38',
#   'date': '2019-12-30T17:00:00.000',
#   'ped_north': '5',
#   'ped_south': '5'},
#  {'bgt_north_of_ne_70th_total': '21',
#   'bike_north': '4',
#   'bike_south': '14',
#   'date': '2019-12-30T18:00:00.000',
#   'ped_north': '1',
#   'ped_south': '2'},
#  {'bgt_north_of_ne_70th_total': '11',
#   'bike_north': '1',
#   'bike_south': '9',
#   'date': '2019-12-30T19:00:00.000',
#   'ped_north': '0',
#   'ped_south': '1'},
#  {'bgt_north_of_ne_70th_total': '3',
#   'bike_north': '1',
#   'bike_south': '2',
#   'date': '2019-12-30T20:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '3',
#   'bike_north': '0',
#   'bike_south': '1',
#   'date': '2019-12-30T21:00:00.000',
#   'ped_north': '0',
#   'ped_south': '2'},
#  {'bgt_north_of_ne_70th_total': '1',
#   'bike_north': '0',
#   'bike_south': '0',
#   'date': '2019-12-30T22:00:00.000',
#   'ped_north': '1',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '1',
#   'bike_north': '0',
#   'bike_south': '1',
#   'date': '2019-12-30T23:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '4',
#   'bike_north': '0',
#   'bike_south': '1',
#   'date': '2019-12-31T00:00:00.000',
#   'ped_north': '1',
#   'ped_south': '2'},
#  {'bgt_north_of_ne_70th_total': '0',
#   'bike_north': '0',
#   'bike_south': '0',
#   'date': '2019-12-31T01:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '3',
#   'bike_north': '0',
#   'bike_south': '0',
#   'date': '2019-12-31T02:00:00.000',
#   'ped_north': '1',
#   'ped_south': '2'},
#  {'bgt_north_of_ne_70th_total': '2',
#   'bike_north': '1',
#   'bike_south': '0',
#   'date': '2019-12-31T03:00:00.000',
#   'ped_north': '1',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '1',
#   'bike_north': '0',
#   'bike_south': '0',
#   'date': '2019-12-31T04:00:00.000',
#   'ped_north': '0',
#   'ped_south': '1'},
#  {'bgt_north_of_ne_70th_total': '2',
#   'bike_north': '1',
#   'bike_south': '0',
#   'date': '2019-12-31T05:00:00.000',
#   'ped_north': '1',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '14',
#   'bike_north': '8',
#   'bike_south': '0',
#   'date': '2019-12-31T06:00:00.000',
#   'ped_north': '3',
#   'ped_south': '3'},
#  {'bgt_north_of_ne_70th_total': '22',
#   'bike_north': '14',
#   'bike_south': '2',
#   'date': '2019-12-31T07:00:00.000',
#   'ped_north': '6',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '39',
#   'bike_north': '14',
#   'bike_south': '3',
#   'date': '2019-12-31T08:00:00.000',
#   'ped_north': '10',
#   'ped_south': '12'},
#  {'bgt_north_of_ne_70th_total': '55',
#   'bike_north': '15',
#   'bike_south': '8',
#   'date': '2019-12-31T09:00:00.000',
#   'ped_north': '14',
#   'ped_south': '18'},
#  {'bgt_north_of_ne_70th_total': '42',
#   'bike_north': '5',
#   'bike_south': '5',
#   'date': '2019-12-31T10:00:00.000',
#   'ped_north': '14',
#   'ped_south': '18'},
#  {'bgt_north_of_ne_70th_total': '56',
#   'bike_north': '11',
#   'bike_south': '11',
#   'date': '2019-12-31T11:00:00.000',
#   'ped_north': '18',
#   'ped_south': '16'},
#  {'bgt_north_of_ne_70th_total': '40',
#   'bike_north': '12',
#   'bike_south': '12',
#   'date': '2019-12-31T12:00:00.000',
#   'ped_north': '10',
#   'ped_south': '6'},
#  {'bgt_north_of_ne_70th_total': '39',
#   'bike_north': '12',
#   'bike_south': '7',
#   'date': '2019-12-31T13:00:00.000',
#   'ped_north': '8',
#   'ped_south': '12'},
#  {'bgt_north_of_ne_70th_total': '47',
#   'bike_north': '7',
#   'bike_south': '13',
#   'date': '2019-12-31T14:00:00.000',
#   'ped_north': '10',
#   'ped_south': '17'},
#  {'bgt_north_of_ne_70th_total': '42',
#   'bike_north': '4',
#   'bike_south': '17',
#   'date': '2019-12-31T15:00:00.000',
#   'ped_north': '11',
#   'ped_south': '10'},
#  {'bgt_north_of_ne_70th_total': '40',
#   'bike_north': '7',
#   'bike_south': '12',
#   'date': '2019-12-31T16:00:00.000',
#   'ped_north': '11',
#   'ped_south': '10'},
#  {'bgt_north_of_ne_70th_total': '14',
#   'bike_north': '1',
#   'bike_south': '9',
#   'date': '2019-12-31T17:00:00.000',
#   'ped_north': '3',
#   'ped_south': '1'},
#  {'bgt_north_of_ne_70th_total': '14',
#   'bike_north': '0',
#   'bike_south': '4',
#   'date': '2019-12-31T18:00:00.000',
#   'ped_north': '6',
#   'ped_south': '4'},
#  {'bgt_north_of_ne_70th_total': '6',
#   'bike_north': '1',
#   'bike_south': '2',
#   'date': '2019-12-31T19:00:00.000',
#   'ped_north': '1',
#   'ped_south': '2'},
#  {'bgt_north_of_ne_70th_total': '2',
#   'bike_north': '0',
#   'bike_south': '2',
#   'date': '2019-12-31T20:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '3',
#   'bike_north': '0',
#   'bike_south': '0',
#   'date': '2019-12-31T21:00:00.000',
#   'ped_north': '2',
#   'ped_south': '1'},
#  {'bgt_north_of_ne_70th_total': '1',
#   'bike_north': '0',
#   'bike_south': '1',
#   'date': '2019-12-31T22:00:00.000',
#   'ped_north': '0',
#   'ped_south': '0'},
#  {'bgt_north_of_ne_70th_total': '2',
#   'bike_north': '1',
#   'bike_south': '0',
#   'date': '2019-12-31T23:00:00.000',
#   'ped_north': '0',
#   'ped_south': '1'}]

# %% [markdown]
# Now that we have our data sample and we know how the data is organized (a list of dictionaries, with one dictionary for each hour of traffic), we can start asking research questions about the data.

# %% [markdown]
# ## Question #1: how many people used the Burke Gilman during commute hours in 2019?
#
# City planners often need to know the traffic volumes on particular roads and trails, so that they can prioritize maintenance and improvements. Anyone who's been on the Burke Gilman on a weekday at 5pm knows that it's a busy thoroughfare, but how busy is it?

# %% [markdown]
# For our first step, we need to decide what we mean by commute hours. Let's say between 6am and 9:59am is the "morning" communte, and 3pm-6:59pm is the "evening commute".
#
# We'll store these values in two lists, so that as we loop through each hour in the dataset later we can check whether the traffic during that hour falls within the morning or evening commute.

# %%
morning_commute_hours = ['06:00:00','07:00:00', '08:00:00', '09:00:00']
evening_commute_hours = ['15:00:00','16:00:00', '17:00:00', '18:00:00']

# %% [markdown]
# Now we need some place to store the morning/evening commute counts, as we loop through the dataset. We'll create a dictionary with keys for 'morning' and 'evening' for this purpose. The values for each of these will start at 0, and increase as we loop through the dataset and add the traffic we see.

# %%
#create an empty dictionary to hold our counts
commuters = {'morning':0, 'evening':0}

# %% [markdown]
# Now we can loop through our ``raw data`` list and examine each dictionary in that list. If the time of day in that dictionary matches one of the times we've listed in our morning and evening commute hour lists we made above, then we take the value of ``bgt_north_of_ne_70th_total`` for that dictionary and add it to one of the totals in ``commuters``. If it doesn't match, we move on to the next one and do the same thing.

# %%
for hour_count in raw_data:

    traffic_hour = hour_count['date'][11:19] #get the timestamp
    
    if traffic_hour in morning_commute_hours: #if it's in the morning, add the count to our morning total
        commuters['morning'] = commuters['morning'] + int(hour_count['bgt_north_of_ne_70th_total'])
    
    elif traffic_hour in evening_commute_hours: #if it's in the evening, add the count to our evening total
        commuters['evening'] = commuters['evening'] + int(hour_count['bgt_north_of_ne_70th_total'])
    
    else:
        pass #we don't care who's on the BGT during non-commute hours, so we ignore it and move on

# %% [markdown]
# ### Understanding the loop we just made

# %% [markdown]
# #### interlude 1: data types
# If you scroll up to our pprinted dataset above, you'll see that the numeric values for ``bgt_north_of_ne_70th_total`` (the hourly traffic counts) have '' around them. This means they are being stored as strings.

# %%
#we can ask Python to tell us what type of value this is using 'type'
print(type(raw_data[0]['bgt_north_of_ne_70th_total']))
# Out:
# <class 'str'>

# %% [markdown]
# If we want to add these numeric values together, we will need to turn them into integers. That's what's happening when you see ``int(hour_count['bgt_north_of_ne_70th_total'])`` in the loop above.

# %%
#converting the string to an integer
str_to_int = int(raw_data[0]['bgt_north_of_ne_70th_total'])

print(type(str_to_int))
# Out:
# <class 'int'>

# %% [markdown]
# #### interlude 2: slicing
# The date and time for each item in the list is stored in a single string, like ``'2019-01-01T06:00:00.000'`` Right now, we are only interested in the time of day, which is in the middle—between "T" (position 10) and "." (position 19), so we slice the beginning and the end of the string off before we compare the value with our commute hour lists.

# %%
print(raw_data[0]['date'])
# Out:
# 2019-01-01T01:00:00.000

# %%
print(raw_data[0]['date'][:11]) #slice the string to just get the stuff before the time
# Out:
# 2019-01-01T

# %%
print(raw_data[0]['date'][19:]) #slice the string to just get the stuff after the time
# Out:
# .000

# %%
print(raw_data[0]['date'][11:19]) #slice the string to just get the time
# Out:
# 01:00:00

# %% [markdown]
# ### Getting the answer to Q1
# Now if our loop above worked, we'll know how many people used the Burke Gilman during commute hours in 2019 (at 70th street, at least)!

# %%
pprint(commuters)
# Out:
# {'evening': 168241, 'morning': 114366}

# %%
#we can make these values into a human readable sentence, if we convert the ints back into strings
print("There were " 
    + str(commuters['morning']) 
    + " morning commuters and " 
    + str(commuters['evening']) 
    + " on the Burke Gilman at 70th Street in 2019!"
     )
# Out:
# There were 114366 morning commuters and 168241 on the Burke Gilman at 70th Street in 2019!

# %% [markdown]
# ## Question 2: what were the busiest hours on the Burke Gilman in 2019?
# Let's say you want to know when the Burke Gilman is least likely to be congested, so you can plan your trip. How would you find this out?

# %% [markdown]
# To do this, we need to start with a list of all of the hours of the day. We could do this manually by creating a list like we did with the morning and evening commute hours lists above, but since there are 24 hours in a day that would take a long time to type out manually! Is there a quicker way?

# %%
#create an empty dictionary, that we will fill with hours
traffic_by_hour = {}

# %%
#loop through the dataset again...
for hour_data in raw_data:
    
    traffic_hour = hour_data['date'][11:19] #grab the hour value from the item
    
    #if haven't seen this hour yet during the loop...
    if traffic_hour not in traffic_by_hour.keys():
        
        # ...create an item for it in our dictionary that we can use later to track our cumulative hourly counts
        traffic_by_hour[traffic_hour] = 0 #e.g {'01:00:00' : 0}
   
    else:
        pass
        #if we've already seen this hour and stored it in our dictionary, ignore it and move on to the next one

# %%
#how many hours in our list?
len(traffic_by_hour)
# Out:
# 24

# %%
#what does our list look like?
pprint(traffic_by_hour)
# Out:
# {'00:00:00': 0,
#  '01:00:00': 0,
#  '02:00:00': 0,
#  '03:00:00': 0,
#  '04:00:00': 0,
#  '05:00:00': 0,
#  '06:00:00': 0,
#  '07:00:00': 0,
#  '08:00:00': 0,
#  '09:00:00': 0,
#  '10:00:00': 0,
#  '11:00:00': 0,
#  '12:00:00': 0,
#  '13:00:00': 0,
#  '14:00:00': 0,
#  '15:00:00': 0,
#  '16:00:00': 0,
#  '17:00:00': 0,
#  '18:00:00': 0,
#  '19:00:00': 0,
#  '20:00:00': 0,
#  '21:00:00': 0,
#  '22:00:00': 0,
#  '23:00:00': 0}

# %% [markdown]
# ## Getting the answer to Q2
# Awesome! Now that we have buckets ready to hold counts for each hour in the day, we can loop through the raw data again and start calculating the traffic counts for each hour.

# %%
for hour_data in raw_data:
    
    traffic_hour = hour_data['date'][11:19]

    traffic_by_hour[traffic_hour] =  traffic_by_hour[traffic_hour] + int(hour_data['bgt_north_of_ne_70th_total'])

    #you can also un-comment the following line and run it instead of the line directly above.
    #this is a slightly shorter way to do the same thing. Re-set traffic_by_hour to zero and try it!
#     traffic_by_hour[traffic_hour] += int(hour_data['bgt_north_of_ne_70th_total'])

# %%
pprint(traffic_by_hour)
# Out:
# {'00:00:00': 343,
#  '01:00:00': 157,
#  '02:00:00': 147,
#  '03:00:00': 203,
#  '04:00:00': 760,
#  '05:00:00': 4304,
#  '06:00:00': 15275,
#  '07:00:00': 25894,
#  '08:00:00': 37369,
#  '09:00:00': 35828,
#  '10:00:00': 36095,
#  '11:00:00': 38024,
#  '12:00:00': 37621,
#  '13:00:00': 38328,
#  '14:00:00': 39132,
#  '15:00:00': 40675,
#  '16:00:00': 46041,
#  '17:00:00': 46997,
#  '18:00:00': 34528,
#  '19:00:00': 18987,
#  '20:00:00': 9167,
#  '21:00:00': 3789,
#  '22:00:00': 1376,
#  '23:00:00': 692}

# %% [markdown]
# It looks like the busiest hour is between 5 and 6pm!

# %% [markdown]
# #### interlude 3: plus-equals
# Writing long lines of code like ``commuters['morning'] = commuters['morning'] + int(hour_count['bgt_north_of_ne_70th_total'])`` can be tedious, and it makes it more likely that you will make a typo that causes your code to crash. There's an easier way!
#
# Instead of writing ``thing_one = thing_one + thing_two``, you can write ``thing_one += thing_two``. It does the same thing!
#
# You can try this out yourself by re-running cells 35-38 above, and then using the code ``traffic_by_hour[traffic_hour] += int(hour_data['bgt_north_of_ne_70th_total'])``
#
# ...instead of the line ``traffic_by_hour[traffic_hour] =  traffic_by_hour[traffic_hour] + int(hour_data['bgt_north_of_ne_70th_total'])``

# %% [markdown]
# ### Going further with Question 3
# - Challenge #1: How would you use Python to find the HOUR with the most traffic? This list is short, so we can probably easily identify the element with the most traffic just by looking at it. But what if it had 10k items in it? How would YOU find the hour with the most traffic?
# - Challegen #2: How would you find the busiest DAY on the Burke Gilman in 2019? You should be able to answer this question with the same techniques you used to find the busiest hour!

# %% [markdown]
# ## Question 3: What is the busiest hours for bikes vs pedestrians?
# One cool thing about this dataset is that it doesn't just count by hour, it counts by what kind of traffic: bikes or pedestrians. Let's run the same set of commands as above, but this time we'll break things apart into bikes and peds.

# %%
#create an empty dictionary
traffic_by_hour_bp = {}

for hour_data in raw_data:
    
    traffic_hour = hour_data['date'][11:19]
    
    #if haven't seen this hour yet, create an item for it that we can use to track hourly counts later
    if traffic_hour not in traffic_by_hour_bp.keys():
        
        #this time, we create a dictionary-in-a-dictionary, to hold our bike and pedestrian counts separately
        traffic_by_hour_bp[traffic_hour] = {'bikes' : 0, 'pedestrians' : 0}
    
    else:
        pass
        #if we've already seen this hour and stored it in our dictionary, ignore it and move on

pprint(traffic_by_hour_bp)
# Out:
# {'00:00:00': {'bikes': 0, 'pedestrians': 0},
#  '01:00:00': {'bikes': 0, 'pedestrians': 0},
#  '02:00:00': {'bikes': 0, 'pedestrians': 0},
#  '03:00:00': {'bikes': 0, 'pedestrians': 0},
#  '04:00:00': {'bikes': 0, 'pedestrians': 0},
#  '05:00:00': {'bikes': 0, 'pedestrians': 0},
#  '06:00:00': {'bikes': 0, 'pedestrians': 0},
#  '07:00:00': {'bikes': 0, 'pedestrians': 0},
#  '08:00:00': {'bikes': 0, 'pedestrians': 0},
#  '09:00:00': {'bikes': 0, 'pedestrians': 0},
#  '10:00:00': {'bikes': 0, 'pedestrians': 0},
#  '11:00:00': {'bikes': 0, 'pedestrians': 0},
#  '12:00:00': {'bikes': 0, 'pedestrians': 0},
#  '13:00:00': {'bikes': 0, 'pedestrians': 0},
#  '14:00:00': {'bikes': 0, 'pedestrians': 0},
#  '15:00:00': {'bikes': 0, 'pedestrians': 0},
#  '16:00:00': {'bikes': 0, 'pedestrians': 0},
#  '17:00:00': {'bikes': 0, 'pedestrians': 0},
#  '18:00:00': {'bikes': 0, 'pedestrians': 0},
#  '19:00:00': {'bikes': 0, 'pedestrians': 0},
#  '20:00:00': {'bikes': 0, 'pedestrians': 0},
#  '21:00:00': {'bikes': 0, 'pedestrians': 0},
#  '22:00:00': {'bikes': 0, 'pedestrians': 0},
#  '23:00:00': {'bikes': 0, 'pedestrians': 0}}

# %% [markdown]
# ## Getting the answer to Q3
# Now that we have the right buckets for every value we want to capture, we're ready to get counts for bikes and peds separately.

# %%
for hour_data in raw_data:
    
    traffic_hour = hour_data['date'][11:19]
    
    #note that we're using the 'plus-equals' technique now, which means we have to write less code
    traffic_by_hour_bp[traffic_hour]['bikes'] += int(hour_data['bike_north']) #add northbound bike counts
    traffic_by_hour_bp[traffic_hour]['bikes'] += int(hour_data['bike_south']) #add southbound bike counts
    
    traffic_by_hour_bp[traffic_hour]['pedestrians'] += int(hour_data['ped_north']) #add northbound ped counts
    traffic_by_hour_bp[traffic_hour]['pedestrians'] += int(hour_data['ped_south']) #add sounthbound ped counts

# %%
pprint(traffic_by_hour_bp)
# Out:
# {'00:00:00': {'bikes': 245, 'pedestrians': 98},
#  '01:00:00': {'bikes': 99, 'pedestrians': 58},
#  '02:00:00': {'bikes': 103, 'pedestrians': 44},
#  '03:00:00': {'bikes': 179, 'pedestrians': 24},
#  '04:00:00': {'bikes': 640, 'pedestrians': 120},
#  '05:00:00': {'bikes': 3375, 'pedestrians': 929},
#  '06:00:00': {'bikes': 11413, 'pedestrians': 3862},
#  '07:00:00': {'bikes': 19422, 'pedestrians': 6472},
#  '08:00:00': {'bikes': 24499, 'pedestrians': 12870},
#  '09:00:00': {'bikes': 21565, 'pedestrians': 14263},
#  '10:00:00': {'bikes': 22624, 'pedestrians': 13471},
#  '11:00:00': {'bikes': 26064, 'pedestrians': 11960},
#  '12:00:00': {'bikes': 26678, 'pedestrians': 10943},
#  '13:00:00': {'bikes': 28166, 'pedestrians': 10162},
#  '14:00:00': {'bikes': 29157, 'pedestrians': 9975},
#  '15:00:00': {'bikes': 30443, 'pedestrians': 10232},
#  '16:00:00': {'bikes': 34648, 'pedestrians': 11393},
#  '17:00:00': {'bikes': 37291, 'pedestrians': 9706},
#  '18:00:00': {'bikes': 26761, 'pedestrians': 7767},
#  '19:00:00': {'bikes': 14101, 'pedestrians': 4886},
#  '20:00:00': {'bikes': 6374, 'pedestrians': 2793},
#  '21:00:00': {'bikes': 2696, 'pedestrians': 1093},
#  '22:00:00': {'bikes': 969, 'pedestrians': 407},
#  '23:00:00': {'bikes': 480, 'pedestrians': 212}}

# %% [markdown]
# Now that there is more data in the notebook, it's a bit harder to figure out the busiest hour for bikes and pedestrians separately, just by looking. So let's use a quick loop to find this.

# %%
top_bike = ['some hour', 0]
top_ped = ['some hour', 0]

for hour, traffic in traffic_by_hour_bp.items():

    if traffic['bikes'] > top_bike[1]:
        top_bike[0] = hour
        top_bike[1] = traffic['bikes']
    else:
        pass
    
    if traffic['pedestrians'] > top_ped[1]:
        top_ped[0] = hour
        top_ped[1] = traffic['pedestrians']
    else:
        pass
    
print("The hour with the most bike traffic is " + top_bike[0] + ", with " + str(top_bike[1]) + " bikes!")
print("The hour with the most pedestrian traffic is " + top_ped[0] + ", with " + str(top_ped[1]) + " pedestrians!")
# Out:
# The hour with the most bike traffic is 17:00:00, with 37291 bikes!
# The hour with the most pedestrian traffic is 09:00:00, with 14263 pedestrians!

# %% [markdown]
# # Going further Question #1
# - Were there more bikes or pedestrians using the Burke Gilman trail in 2019?
# Use the block below and try to answer this question.

# %%
# Code for Question 1 goes here.
import pandas as pd

df = pd.DataFrame(raw_data)
df = df.set_index(pd.to_datetime(df['date']))
del df['date']
for col in ('ped_south','ped_north','bike_north','bike_south','bgt_north_of_ne_70th_total'):
    df[col] = df[col].astype(int)
df.head()
# Out:
#                      bgt_north_of_ne_70th_total  ped_south  ped_north  \
# date
# 2019-01-01 01:00:00                           2          1          0
# 2019-01-01 02:00:00                           1          0          0
# 2019-01-01 03:00:00                           0          0          0
# 2019-01-01 04:00:00                           1          0          0
# 2019-01-01 05:00:00                           1          0          0
#
#                      bike_north  bike_south
# date
# 2019-01-01 01:00:00           1           0
# 2019-01-01 02:00:00           0           1
# 2019-01-01 03:00:00           0           0
# 2019-01-01 04:00:00           1           0
# 2019-01-01 05:00:00           1           0

# %%
peds = df['ped_north'].sum()
bikes = df['bike_north'].sum()
print("There were more {0} using the Burke Gilman trail in 2019.".format("bikes" if bikes > peds else "pedestrians"))
print("({0} bikes versus {1} pedestrians)".format(bikes, peds))
# Out:
# There were more bikes using the Burke Gilman trail in 2019.
# (174091 bikes versus 73253 pedestrians)

# %% [markdown]
# ## Question 4: What is the busiest hour for bikes vs. peds AND northbound vs. southbound?
#
# If we want, we can break our data down by bikes vs. peds AND northbound vs. southbound. This is useful because it helps us understand how many people are using the Burke Gilman trail for daily commuting, not just for pleasure trips.
#
# Splitting bike and pedestrian traffic by northboud/southbound is actually almost as easy as lumping them together. We just make our dictionary-in-a-dictionary a little more complex.

# %%
#create a new empty dictionary
traffic_by_hour_bpd = {}

for hour_data in raw_data:
    
    traffic_hour = hour_data['date'][11:19]
    
    if traffic_hour not in traffic_by_hour_bpd.keys():

        traffic_by_hour_bpd[traffic_hour] = {'bikes north' : 0, 'pedestrians north' : 0, 
                                            'bikes south' : 0, 'pedestrians south' : 0}  
    else:
        pass

pprint(traffic_by_hour_bpd)
# Out:
# {'00:00:00': {'bikes north': 0,
#               'bikes south': 0,
#               'pedestrians north': 0,
#               'pedestrians south': 0},
#  '01:00:00': {'bikes north': 0,
#               'bikes south': 0,
#               'pedestrians north': 0,
#               'pedestrians south': 0},
#  '02:00:00': {'bikes north': 0,
#               'bikes south': 0,
#               'pedestrians north': 0,
#               'pedestrians south': 0},
#  '03:00:00': {'bikes north': 0,
#               'bikes south': 0,
#               'pedestrians north': 0,
#               'pedestrians south': 0},
#  '04:00:00': {'bikes north': 0,
#               'bikes south': 0,
#               'pedestrians north': 0,
#               'pedestrians south': 0},
#  '05:00:00': {'bikes north': 0,
#               'bikes south': 0,
#               'pedestrians north': 0,
#               'pedestrians south': 0},
#  '06:00:00': {'bikes north': 0,
#               'bikes south': 0,
#               'pedestrians north': 0,
#               'pedestrians south': 0},
#  '07:00:00': {'bikes north': 0,
#               'bikes south': 0,
#               'pedestrians north': 0,
#               'pedestrians south': 0},
#  '08:00:00': {'bikes north': 0,
#               'bikes south': 0,
#               'pedestrians north': 0,
#               'pedestrians south': 0},
#  '09:00:00': {'bikes north': 0,
#               'bikes south': 0,
#               'pedestrians north': 0,
#               'pedestrians south': 0},
#  '10:00:00': {'bikes north': 0,
#               'bikes south': 0,
#               'pedestrians north': 0,
#               'pedestrians south': 0},
#  '11:00:00': {'bikes north': 0,
#               'bikes south': 0,
#               'pedestrians north': 0,
#               'pedestrians south': 0},
#  '12:00:00': {'bikes north': 0,
#               'bikes south': 0,
#               'pedestrians north': 0,
#               'pedestrians south': 0},
#  '13:00:00': {'bikes north': 0,
#               'bikes south': 0,
#               'pedestrians north': 0,
#               'pedestrians south': 0},
#  '14:00:00': {'bikes north': 0,
#               'bikes south': 0,
#               'pedestrians north': 0,
#               'pedestrians south': 0},
#  '15:00:00': {'bikes north': 0,
#               'bikes south': 0,
#               'pedestrians north': 0,
#               'pedestrians south': 0},
#  '16:00:00': {'bikes north': 0,
#               'bikes south': 0,
#               'pedestrians north': 0,
#               'pedestrians south': 0},
#  '17:00:00': {'bikes north': 0,
#               'bikes south': 0,
#               'pedestrians north': 0,
#               'pedestrians south': 0},
#  '18:00:00': {'bikes north': 0,
#               'bikes south': 0,
#               'pedestrians north': 0,
#               'pedestrians south': 0},
#  '19:00:00': {'bikes north': 0,
#               'bikes south': 0,
#               'pedestrians north': 0,
#               'pedestrians south': 0},
#  '20:00:00': {'bikes north': 0,
#               'bikes south': 0,
#               'pedestrians north': 0,
#               'pedestrians south': 0},
#  '21:00:00': {'bikes north': 0,
#               'bikes south': 0,
#               'pedestrians north': 0,
#               'pedestrians south': 0},
#  '22:00:00': {'bikes north': 0,
#               'bikes south': 0,
#               'pedestrians north': 0,
#               'pedestrians south': 0},
#  '23:00:00': {'bikes north': 0,
#               'bikes south': 0,
#               'pedestrians north': 0,
#               'pedestrians south': 0}}

# %% [markdown]
# And now instead of adding bike_north + bike_south etc together, we store each of those counts in their own key/value bucket.

# %%
for hour_data in raw_data:
    
    traffic_hour = hour_data['date'][11:19]
    
    traffic_by_hour_bpd[traffic_hour]['bikes north'] += int(hour_data['bike_north']) #store count in bike_north
    traffic_by_hour_bpd[traffic_hour]['bikes south'] += int(hour_data['bike_south']) #store count in bike_south
    
    traffic_by_hour_bpd[traffic_hour]['pedestrians north'] += int(hour_data['ped_north'])
    traffic_by_hour_bpd[traffic_hour]['pedestrians south'] += int(hour_data['ped_south'])

pprint(traffic_by_hour_bpd)
# Out:
# {'00:00:00': {'bikes north': 57,
#               'bikes south': 188,
#               'pedestrians north': 50,
#               'pedestrians south': 48},
#  '01:00:00': {'bikes north': 30,
#               'bikes south': 69,
#               'pedestrians north': 31,
#               'pedestrians south': 27},
#  '02:00:00': {'bikes north': 18,
#               'bikes south': 85,
#               'pedestrians north': 21,
#               'pedestrians south': 23},
#  '03:00:00': {'bikes north': 77,
#               'bikes south': 102,
#               'pedestrians north': 11,
#               'pedestrians south': 13},
#  '04:00:00': {'bikes north': 474,
#               'bikes south': 166,
#               'pedestrians north': 55,
#               'pedestrians south': 65},
#  '05:00:00': {'bikes north': 2399,
#               'bikes south': 976,
#               'pedestrians north': 416,
#               'pedestrians south': 513},
#  '06:00:00': {'bikes north': 7825,
#               'bikes south': 3588,
#               'pedestrians north': 2023,
#               'pedestrians south': 1839},
#  '07:00:00': {'bikes north': 13207,
#               'bikes south': 6215,
#               'pedestrians north': 3425,
#               'pedestrians south': 3047},
#  '08:00:00': {'bikes north': 16379,
#               'bikes south': 8120,
#               'pedestrians north': 6236,
#               'pedestrians south': 6634},
#  '09:00:00': {'bikes north': 11410,
#               'bikes south': 10155,
#               'pedestrians north': 7637,
#               'pedestrians south': 6626},
#  '10:00:00': {'bikes north': 10517,
#               'bikes south': 12107,
#               'pedestrians north': 6805,
#               'pedestrians south': 6666},
#  '11:00:00': {'bikes north': 12097,
#               'bikes south': 13967,
#               'pedestrians north': 5997,
#               'pedestrians south': 5963},
#  '12:00:00': {'bikes north': 12782,
#               'bikes south': 13896,
#               'pedestrians north': 5671,
#               'pedestrians south': 5272},
#  '13:00:00': {'bikes north': 12944,
#               'bikes south': 15222,
#               'pedestrians north': 5355,
#               'pedestrians south': 4807},
#  '14:00:00': {'bikes north': 13383,
#               'bikes south': 15774,
#               'pedestrians north': 5067,
#               'pedestrians south': 4908},
#  '15:00:00': {'bikes north': 13851,
#               'bikes south': 16592,
#               'pedestrians north': 5143,
#               'pedestrians south': 5089},
#  '16:00:00': {'bikes north': 13858,
#               'bikes south': 20790,
#               'pedestrians north': 5680,
#               'pedestrians south': 5713},
#  '17:00:00': {'bikes north': 12569,
#               'bikes south': 24722,
#               'pedestrians north': 4765,
#               'pedestrians south': 4941},
#  '18:00:00': {'bikes north': 9285,
#               'bikes south': 17476,
#               'pedestrians north': 3841,
#               'pedestrians south': 3926},
#  '19:00:00': {'bikes north': 5986,
#               'bikes south': 8115,
#               'pedestrians north': 2562,
#               'pedestrians south': 2324},
#  '20:00:00': {'bikes north': 3024,
#               'bikes south': 3350,
#               'pedestrians north': 1525,
#               'pedestrians south': 1268},
#  '21:00:00': {'bikes north': 1360,
#               'bikes south': 1336,
#               'pedestrians north': 628,
#               'pedestrians south': 465},
#  '22:00:00': {'bikes north': 405,
#               'bikes south': 564,
#               'pedestrians north': 200,
#               'pedestrians south': 207},
#  '23:00:00': {'bikes north': 154,
#               'bikes south': 326,
#               'pedestrians north': 109,
#               'pedestrians south': 103}}

# %% [markdown]
# ### Answering question 4
# I will leave it up to you to find the answer to any of these questions (you already know how to do it!)
# - What is the busiest hour for northbound bike traffic? For southbound bike traffic?
# - What is the busiest hour for northbound pedestrian traffic? For southbound pedestrian traffic?
#
# If you don't feel like writing code to answer these questions right now, that's okay. Below, I will show you how to export this data in a format that can be used to easily create timeseries graphs in a spreadsheet. It will be much easier to answer these questions with a graph than by looking at rows of numbers!

# %%
import time

df['hour'] = df.index.hour
hour_group = df.groupby('hour')
for col in ('bike_north','bike_south','ped_north','ped_south'):
    busiest_hr = hour_group[col].sum().idxmax()
    print("Busiest hour for {0}: {1}".format(col, time.strftime('%I:%M %p', (0, 0, 0, busiest_hr, 0, 0, 0, 0, 0))))
# Out:
# Busiest hour for bike_north: 08:00 AM
# Busiest hour for bike_south: 05:00 PM
# Busiest hour for ped_north: 09:00 AM
# Busiest hour for ped_south: 10:00 AM

# %% [markdown]
# ## Exporting the bike/ped north/south dataset for visualization

# %% [markdown]
# Now we have some nice rich data that we can graph in a spreadsheet program like Google Sheets or Microsoft Excel.
#
# But to do that, we will need to convert the data to CSV format and export it into a file. We ideally want a format that has a row for each hour, and columns like
# ``hour_of_day | bikes_north | bikes_south | pedestrians_north | pedestrians_south``
#
# The best way to do this is to convert our data from a nested dictionary to a nested list (a list-of-lists!), where each sub-list (which will be a row in our CSV file), contains the values in a consistent order, like:
#
# ``[hour_of_day, bike_north, bike_south, ped_north, ped_south]``

# %%
#create a new empty 'master list'
traffic_by_hour_mode_direction = []

#for each hour in our traffic-by-hour-mode-direction dictionary...
for hour, counts in traffic_by_hour_bpd.items():
    
    #...create a new sub-list that will store the hour, bike, and pedestrian data in a consistent order
    list_element = [] #new empty sub-list
    list_element.append(hour) #add the hour in, e.g. ['06:00:00']
    list_element.append(counts['bikes north']) #append bike north count, e.g. ['06:00:00', 484]
    list_element.append(counts['bikes south']) #append bike south count, e.g. ['06:00:00', 484, 82]
    list_element.append(counts['pedestrians north']) # etc...
    list_element.append(counts['pedestrians south']) # etc... 
    
    traffic_by_hour_mode_direction.append(list_element) #add this list to the end of our growing master list

# %%
pprint(traffic_by_hour_mode_direction)
# Out:
# [['01:00:00', 30, 69, 31, 27],
#  ['02:00:00', 18, 85, 21, 23],
#  ['03:00:00', 77, 102, 11, 13],
#  ['04:00:00', 474, 166, 55, 65],
#  ['05:00:00', 2399, 976, 416, 513],
#  ['06:00:00', 7825, 3588, 2023, 1839],
#  ['07:00:00', 13207, 6215, 3425, 3047],
#  ['08:00:00', 16379, 8120, 6236, 6634],
#  ['09:00:00', 11410, 10155, 7637, 6626],
#  ['10:00:00', 10517, 12107, 6805, 6666],
#  ['11:00:00', 12097, 13967, 5997, 5963],
#  ['12:00:00', 12782, 13896, 5671, 5272],
#  ['13:00:00', 12944, 15222, 5355, 4807],
#  ['14:00:00', 13383, 15774, 5067, 4908],
#  ['15:00:00', 13851, 16592, 5143, 5089],
#  ['16:00:00', 13858, 20790, 5680, 5713],
#  ['17:00:00', 12569, 24722, 4765, 4941],
#  ['18:00:00', 9285, 17476, 3841, 3926],
#  ['19:00:00', 5986, 8115, 2562, 2324],
#  ['20:00:00', 3024, 3350, 1525, 1268],
#  ['21:00:00', 1360, 1336, 628, 465],
#  ['22:00:00', 405, 564, 200, 207],
#  ['23:00:00', 154, 326, 109, 103],
#  ['00:00:00', 57, 188, 50, 48]]

# %% [markdown]
# This worked! BUT something odd happened. Can you see it? For some reason, our '00:00:00' hour got moved to the end of the list.
#
# This happened because Python dictionaries do not reliably preserve the order of items! So even though the data looked like it was in the right order when we had it in the dictionary, when we created our new master list from ``traffic_by_hour_bpd`` it ended up a little out of order.
#
# Fortunately, unlike dictionaries, lists-of-lists are easy to sort! Especially if you want to sort by the first item in each sub-list, which we do!

# %%
#sort the list in 'alphabetical order' by the first sub-item, which is the hour stamp
traffic_by_hour_mode_direction.sort()

# %%
pprint(traffic_by_hour_mode_direction)
# Out:
# [['00:00:00', 57, 188, 50, 48],
#  ['01:00:00', 30, 69, 31, 27],
#  ['02:00:00', 18, 85, 21, 23],
#  ['03:00:00', 77, 102, 11, 13],
#  ['04:00:00', 474, 166, 55, 65],
#  ['05:00:00', 2399, 976, 416, 513],
#  ['06:00:00', 7825, 3588, 2023, 1839],
#  ['07:00:00', 13207, 6215, 3425, 3047],
#  ['08:00:00', 16379, 8120, 6236, 6634],
#  ['09:00:00', 11410, 10155, 7637, 6626],
#  ['10:00:00', 10517, 12107, 6805, 6666],
#  ['11:00:00', 12097, 13967, 5997, 5963],
#  ['12:00:00', 12782, 13896, 5671, 5272],
#  ['13:00:00', 12944, 15222, 5355, 4807],
#  ['14:00:00', 13383, 15774, 5067, 4908],
#  ['15:00:00', 13851, 16592, 5143, 5089],
#  ['16:00:00', 13858, 20790, 5680, 5713],
#  ['17:00:00', 12569, 24722, 4765, 4941],
#  ['18:00:00', 9285, 17476, 3841, 3926],
#  ['19:00:00', 5986, 8115, 2562, 2324],
#  ['20:00:00', 3024, 3350, 1525, 1268],
#  ['21:00:00', 1360, 1336, 628, 465],
#  ['22:00:00', 405, 564, 200, 207],
#  ['23:00:00', 154, 326, 109, 103]]

# %% [markdown]
# Now that we have our data in a list, it's easy to export to a CSV file!

# %%
import csv

# %%
with open('bg_traffic_bike_ped_2019.csv', 'w', encoding='utf-8') as f:
    writer = csv.writer(f)
    #write a header row
    writer.writerow(('hour of the day', 
                     'northbound bikes', 
                     'southbound bikes', 
                     'northbound pedestrians',
                     'southbound pedestrians'))
    
    for i in traffic_by_hour_mode_direction:
        writer.writerow((i[0], i[1], i[2], i[3], i[4]))

# %% [markdown]
# Generate a plot of the data

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from datetime import datetime
import numpy as np

# Transpose the above data for use in matplotlib
plotdata = np.array(traffic_by_hour_mode_direction).T

# Parse the times so matplotlib can work with them
times = [datetime.strptime(t, '%H:%M:%S') for t in plotdata[0]]

fig, ax = plt.subplots()
for idx, lbl in zip(range(1, 5), ('Bikes North','Bikes South','Peds North','Peds South')):
    ax.plot(times, plotdata[idx].astype(int), label=lbl)
ax.legend()
# Apply a date formatter to show just the time
fmt = mdates.DateFormatter('%I:%M %p')
ax.xaxis.set_major_formatter(fmt)

ax.set(title="Total Hourly Traffic on Burke-Gilman at NE 70th St Counter, 2019", ylabel="Yearly total", xlim=(times[0], times[-1]))
fig.autofmt_xdate()

fig.savefig('bg_traffic_bike_ped_2019.png')

# %% [markdown]
# ## Question 5 (Grand challenge!): What day of the week is busiest on the Burke Gilman?
#
# If we really want to understand whether people use the Burke Gilman for commuting, rather than just for recreation, we probably need to know what days of the week are busiest.
#
# We can answer this question using the same basic approach we used to answer the previous questions, but we will need a little bit of help. Since days of the week occur on different calendar days every year, we need a way to find out, for any given date in 2019, what day of the week that date fell on.
#
# Python has a couple of tools that can help us with this:
# - ``parse`` is a function from the ``dateutil`` library that can turn a date that is formatted as a string into a "datetime object", which is a format that Python understands as a real date, not just a series of characters.
# - ``weekday`` is a function from the ``datetime`` library that can tell you, for any valid datetime object, what day of the week that date fell on.

# %%
from datetime import datetime #yes, I know this seems redundant
from dateutil import parser

# %% [markdown]
# Let's try out formatting one of our strings as a datetime object.

# %%
#here's a random date from our dataset, in its native string format
print(raw_data[234]['date'])
# Out:
# 2019-01-10T19:00:00.000

# %%
#now let's use the parse function to turn that into datetime format, which Python can work with
parser.parse(raw_data[234]['date'])
# Out:
# datetime.datetime(2019, 1, 10, 19, 0)

# %% [markdown]
# That worked! We can save this datetime object in its own variable. That will let us do things with it (like find out what day of the week January 10th, 2019 was).

# %%
my_date = parser.parse(raw_data[234]['date'])
print(my_date)
print(type(my_date))
# Out:
# 2019-01-10 19:00:00
# <class 'datetime.datetime'>

# %% [markdown]
# Now that we know how to parse strings into datetime objects, we can use the ``datetime.weekday()`` function to find out what day of the week it was. This function will return a value between 0 (Monday) and 6 (Sunday) for any valid date you give it.

# %%
my_date.weekday() #starts at 0!
# Out:
# 3

# %% [markdown]
# Looks like January 10th was a Thursday (you can check your calendar to confirm this).

# %% [markdown]
# ### Answering Question 5
# Now that you know how to find out the day of the week for any date in our ``raw_data`` dataset, you should be able to find out which weekday or weekend day sees the most traffic on the Burke Gilman. You'll be able to use loops, "if" statements, and dictionaries to calculate the totals for each day.
#
# Before you start, think for a minute: what do you think the answer will be, based on your own experience or your prior knowledge? Do you think the Burke Gilman is used more on weekdays or weekends? Why? Are some weekdays busier than others? Why?

# %%
df['dow'] = df.index.dayofweek
df.head()
# Out:
#                      bgt_north_of_ne_70th_total  ped_south  ped_north  \
# date
# 2019-01-01 01:00:00                           2          1          0
# 2019-01-01 02:00:00                           1          0          0
# 2019-01-01 03:00:00                           0          0          0
# 2019-01-01 04:00:00                           1          0          0
# 2019-01-01 05:00:00                           1          0          0
#
#                      bike_north  bike_south  hour  dow
# date
# 2019-01-01 01:00:00           1           0     1    1
# 2019-01-01 02:00:00           0           1     2    1
# 2019-01-01 03:00:00           0           0     3    1
# 2019-01-01 04:00:00           1           0     4    1
# 2019-01-01 05:00:00           1           0     5    1

# %% [markdown]
# From checking a calendar, Jan 1 was a Tuesday and is given day-of-week number 1. So the days of the week are 0-indexed from Monday to Sunday.

# %%
df['total'] = df['bike_north'] + df['bike_south'] + df['ped_north'] + df['ped_south']
group = df.groupby('dow')
group['total'].sum()
# Out:
# dow
# 0    68789
# 1    66125
# 2    64235
# 3    63140
# 4    61180
# 5    92801
# 6    95462
# Name: total, dtype: int64

# %% [markdown]
# The above shows that Sunday (day of week 6) had the most traffic, so it was the busiest day.

# %% [markdown]
# # Congratulations!
#
# You have now mastered manipulating timeseries data in Python. There are plenty of other techniques, tools, and time-saving tricks that you can learn to build on these skills, but many data scientists who use Python every day do this kind of work using the same basic approach you just learned.

# %% [markdown]
# ## Challenges: going further
#
# Here are some additional questions that you now have the tools you need to answer, based on what you've done today:
#
# - what day of the week is busiest for bikes? Is it the same as the busiest day for pedestrians?
# - what month of the year is busiest? (aka do Seattlites really like to ride in the rain?)
# - has the Burke Gilman gotten busier over time? (the dataset we have goes back to 2014!)
# - do fewer people commute on the Burke Gilman when it's cold out? (hint: try combining this dataset with the [dataset on road temperature over time](https://data.seattle.gov/Public-Safety/Road-Weather-Information-Stations/egc4-d24i/data)
# - do more people commute into Seattle in the mornings by bike on the Burke Gilman, or on the [the Mountain to Sound Trail](https://data.seattle.gov/Transportation/MTS-Trail-west-of-I-90-Bridge-Bicycle-and-Pedestri/u38e-ybnc)?

# %% [markdown]
# ## Other data.seattle.gov datasets that you can do timeseries with...
# - Fremont bridge bicycle counter: https://data.seattle.gov/Transportation/Fremont-Bridge-Bicycle-Counter/65db-xm6k
# - Spokane Street bridge bicycle counter: https://data.seattle.gov/Transportation/Spokane-St-Bridge-Bicycle-Counter/upms-nr8w
# - Mountain to Sound trail bicycle + pedestrian counter: https://data.seattle.gov/Transportation/MTS-Trail-west-of-I-90-Bridge-Bicycle-and-Pedestri/u38e-ybnc

# %% [markdown]
# ## More complex datasets

# %% [markdown]
# - https://data.seattle.gov/Public-Safety/Terry-Stops/28ny-9ts8
# - https://data.seattle.gov/Permitting/Building-Permits/76t5-zqzr
